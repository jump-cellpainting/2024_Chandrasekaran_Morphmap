# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %% [markdown]
# Rules
# - Drop Correlation features
# - Drop Object Number features
# - Drop features with X,Y suffix
# - Drop correlations between same compartment features
# - Drop correlations between same Feature categories
# - Keep only one row per feature group
# - Keep only highly correlated/anticorrelated features

# %%
feature_name_cols = ["Compartment", "Feature", "Feature_1", "Feature_2", "Feature_3", "Channel", "Suffix"]

# %%
orf_feature_df = pd.read_parquet("input/orf_feature_wide.parquet").rename(
    columns={"Mask": "Compartment"}
)

# Split Feature further
orf_feature_df[["Feature_1", "Feature_2", "Feature_3"]] = (
    orf_feature_df.Feature.str.split("_", expand=True)
)

# Remove leading underscore from column values

orf_feature_df["Suffix"] = orf_feature_df["Suffix"].apply(lambda x: x.lstrip("_"))

# Create feature name
orf_feature_df["feature_name"] = orf_feature_df[feature_name_cols].agg(
    lambda x: "_".join(filter(None, x)), axis=1
)

orf_feature_df.head()
# Out:
#   Compartment                    Feature Channel     Suffix  column_0  \
# 0       Cells       AreaShapeCompactness                     1.000000
# 1       Cells           AreaShapeZernike                6_6 -0.151370
# 2       Cells        Texture_Correlation     AGP   3_01_256 -0.101507
# 3       Cells  Texture_DifferenceEntropy    Mito   5_03_256 -0.059984
# 4       Cells            Texture_Entropy      ER  10_00_256 -0.057121
#
#    column_1  column_2  column_3  column_4  column_5  ...  column_3630  \
# 0 -0.151370 -0.101507 -0.059984 -0.057121 -0.105450  ...     0.022632
# 1  1.000000 -0.119333  0.031895  0.037169 -0.025448  ...     0.000272
# 2 -0.119333  1.000000 -0.074286 -0.229202  0.208070  ...    -0.270294
# 3  0.031895 -0.074286  1.000000  0.248083  0.573112  ...     0.097819
# 4  0.037169 -0.229202  0.248083  1.000000  0.000372  ...     0.555658
#
#    column_3631  column_3632  column_3633  column_3634  column_3635  \
# 0    -0.061216    -0.005541    -0.093061    -0.108426    -0.075014
# 1    -0.045915    -0.003861    -0.026430    -0.077761    -0.064110
# 2    -0.092594    -0.175566     0.078074     0.023241    -0.097288
# 3     0.136732     0.066876     0.777491     0.513563     0.168530
# 4     0.723166     0.506062     0.050585     0.065895     0.478547
#
#               Feature_1          Feature_2  Feature_3  \
# 0  AreaShapeCompactness               None       None
# 1      AreaShapeZernike               None       None
# 2               Texture        Correlation       None
# 3               Texture  DifferenceEntropy       None
# 4               Texture            Entropy       None
#
#                                         feature_name
# 0    Cells_AreaShapeCompactness_AreaShapeCompactness
# 1        Cells_AreaShapeZernike_AreaShapeZernike_6_6
# 2  Cells_Texture_Correlation_Texture_Correlation_...
# 3  Cells_Texture_DifferenceEntropy_Texture_Differ...
# 4  Cells_Texture_Entropy_Texture_Entropy_ER_10_00...
#
# [5 rows x 3644 columns]

# %%
# Rename column names 

feature_names_df = orf_feature_df[feature_name_cols + ["feature_name"]].copy()
correlation_df = orf_feature_df.drop(columns=feature_name_cols).set_index("feature_name")
correlation_df.columns = feature_names_df.feature_name.to_list()

# %%
# Remove Correlation features
feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Correlation")
]

# Remove Object Number features

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("ObjectNumber")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Object_Number")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("X")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("Y")
]


correlation_df = correlation_df.loc[
    feature_names_df.feature_name.to_list(), feature_names_df.feature_name.to_list()
]

# %%
# Stack the dataframe

correlation_df_stacked = (
    correlation_df.mask(np.tril(np.ones(correlation_df.shape)).astype(bool))
    .stack()
    .reset_index()
    .rename(
        columns={
            0: "correlation",
            "feature_name": "feature_name_1",
            "level_1": "feature_name_2",
        }
    )
).sort_values(by=["correlation"], ascending=False)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 2823858  Cytoplasm_AreaShapeBoundingBoxArea_AreaShapeBo...
# 3406061  Cells_NeighborsSecondClosestDistance_Neighbors...
# 879837   Cells_NeighborsAngleBetweenNeighbors_Neighbors...
# 1861691  Cells_AreaShapeMaxFeretDiameter_AreaShapeMaxFe...
# 2970722  Cells_NeighborsFirstClosestDistance_NeighborsF...
# ...                                                    ...
# 858224   Cytoplasm_RadialDistribution_FracAtD_RadialDis...
# 4937895  Nuclei_Texture_InverseDifferenceMoment_Texture...
# 2033056  Nuclei_Texture_Entropy_Texture_Entropy_AGP_3_0...
# 4745297  Nuclei_Texture_Entropy_Texture_Entropy_Mito_3_...
# 4774555  Nuclei_Texture_Entropy_Texture_Entropy_AGP_3_0...
#
#                                             feature_name_2  correlation
# 2823858  Cells_AreaShapeBoundingBoxArea_AreaShapeBoundi...     1.000000
# 3406061  Cells_NeighborsSecondClosestDistance_Neighbors...     1.000000
# 879837   Cells_NeighborsAngleBetweenNeighbors_Neighbors...     1.000000
# 1861691  Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...     1.000000
# 2970722  Cells_NeighborsFirstClosestDistance_NeighborsF...     1.000000
# ...                                                    ...          ...
# 858224   Cytoplasm_RadialDistribution_FracAtD_RadialDis...    -0.990500
# 4937895  Nuclei_Texture_Entropy_Texture_Entropy_Mito_3_...    -0.990562
# 2033056  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.990900
# 4745297  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.990912
# 4774555  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.991062
#
# [5086455 rows x 3 columns]

# %%
# Add other feature name columns

correlation_df_stacked = (
    correlation_df_stacked.merge(
        feature_names_df, left_on="feature_name_1", right_on="feature_name", how="left"
    )
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_1",
            "Channel": "Channel_1",
            "Suffix": "Suffix_1",
            "Feature_1": "Feature_1_1",
            "Feature_2": "Feature_2_1",
            "Feature_3": "Feature_3_1",
        }
    )
    .merge(feature_names_df, left_on="feature_name_2", right_on="feature_name", how="left")
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_2",
            "Channel": "Channel_2",
            "Suffix": "Suffix_2",
            "Feature_1": "Feature_1_2",
            "Feature_2": "Feature_2_2",
            "Feature_3": "Feature_3_2",
        }
    )
)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 0        Cytoplasm_AreaShapeBoundingBoxArea_AreaShapeBo...
# 1        Cells_NeighborsSecondClosestDistance_Neighbors...
# 2        Cells_NeighborsAngleBetweenNeighbors_Neighbors...
# 3        Cells_AreaShapeMaxFeretDiameter_AreaShapeMaxFe...
# 4        Cells_NeighborsFirstClosestDistance_NeighborsF...
# ...                                                    ...
# 5086450  Cytoplasm_RadialDistribution_FracAtD_RadialDis...
# 5086451  Nuclei_Texture_InverseDifferenceMoment_Texture...
# 5086452  Nuclei_Texture_Entropy_Texture_Entropy_AGP_3_0...
# 5086453  Nuclei_Texture_Entropy_Texture_Entropy_Mito_3_...
# 5086454  Nuclei_Texture_Entropy_Texture_Entropy_AGP_3_0...
#
#                                             feature_name_2  correlation  \
# 0        Cells_AreaShapeBoundingBoxArea_AreaShapeBoundi...     1.000000
# 1        Cells_NeighborsSecondClosestDistance_Neighbors...     1.000000
# 2        Cells_NeighborsAngleBetweenNeighbors_Neighbors...     1.000000
# 3        Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...     1.000000
# 4        Cells_NeighborsFirstClosestDistance_NeighborsF...     1.000000
# ...                                                    ...          ...
# 5086450  Cytoplasm_RadialDistribution_FracAtD_RadialDis...    -0.990500
# 5086451  Nuclei_Texture_Entropy_Texture_Entropy_Mito_3_...    -0.990562
# 5086452  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.990900
# 5086453  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.990912
# 5086454  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.991062
#
#         Compartment_1                     Feature_1_1  \
# 0           Cytoplasm        AreaShapeBoundingBoxArea
# 1               Cells  NeighborsSecondClosestDistance
# 2               Cells  NeighborsAngleBetweenNeighbors
# 3               Cells       AreaShapeMaxFeretDiameter
# 4               Cells   NeighborsFirstClosestDistance
# ...               ...                             ...
# 5086450     Cytoplasm              RadialDistribution
# 5086451        Nuclei                         Texture
# 5086452        Nuclei                         Texture
# 5086453        Nuclei                         Texture
# 5086454        Nuclei                         Texture
#
#                      Feature_2_1 Feature_3_1 Channel_1  Suffix_1  \
# 0                           None        None
# 1                           None        None            Adjacent
# 2                           None        None            Adjacent
# 3                           None        None
# 4                           None        None                   5
# ...                          ...         ...       ...       ...
# 5086450                  FracAtD        None       DNA      3of4
# 5086451  InverseDifferenceMoment        None      Mito  5_02_256
# 5086452                  Entropy        None       AGP  3_03_256
# 5086453                  Entropy        None      Mito  3_00_256
# 5086454                  Entropy        None       AGP  3_01_256
#
#         Compartment_2                     Feature_1_2  \
# 0               Cells        AreaShapeBoundingBoxArea
# 1               Cells  NeighborsSecondClosestDistance
# 2               Cells  NeighborsAngleBetweenNeighbors
# 3           Cytoplasm       AreaShapeMaxFeretDiameter
# 4               Cells   NeighborsFirstClosestDistance
# ...               ...                             ...
# 5086450     Cytoplasm              RadialDistribution
# 5086451        Nuclei                         Texture
# 5086452        Nuclei                         Texture
# 5086453        Nuclei                         Texture
# 5086454        Nuclei                         Texture
#
#                      Feature_2_2 Feature_3_2 Channel_2  Suffix_2
# 0                           None        None
# 1                           None        None                   5
# 2                           None        None                   5
# 3                           None        None
# 4                           None        None            Adjacent
# ...                          ...         ...       ...       ...
# 5086450                  FracAtD        None       DNA      4of4
# 5086451                  Entropy        None      Mito  3_02_256
# 5086452  InverseDifferenceMoment        None       AGP  5_03_256
# 5086453  InverseDifferenceMoment        None      Mito  5_00_256
# 5086454  InverseDifferenceMoment        None       AGP  5_01_256
#
# [5086455 rows x 15 columns]

# %%
# Drop correlations between same compartment features

correlation_df_stacked = correlation_df_stacked.query("Compartment_1!=Compartment_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 0        Cytoplasm_AreaShapeBoundingBoxArea_AreaShapeBo...
# 3        Cells_AreaShapeMaxFeretDiameter_AreaShapeMaxFe...
# 7        Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...
# 8        Cytoplasm_Intensity_MinIntensityEdge_Intensity...
# 9               Cytoplasm_NumberObject_NumberObject_Number
# ...                                                    ...
# 5086181  Cytoplasm_Texture_DifferenceEntropy_Texture_Di...
# 5086182  Cells_Texture_SumEntropy_Texture_SumEntropy_DN...
# 5086216  Cells_Texture_InverseDifferenceMoment_Texture_...
# 5086269  Cells_Texture_InverseDifferenceMoment_Texture_...
# 5086295  Cells_Texture_InverseDifferenceMoment_Texture_...
#
#                                             feature_name_2  correlation  \
# 0        Cells_AreaShapeBoundingBoxArea_AreaShapeBoundi...     1.000000
# 3        Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...     1.000000
# 7        Cells_AreaShapeMinFeretDiameter_AreaShapeMinFe...     1.000000
# 8        Cells_Intensity_MinIntensityEdge_Intensity_Min...     1.000000
# 9                  Nuclei_NumberObject_NumberObject_Number     1.000000
# ...                                                    ...          ...
# 5086181  Cells_Texture_InverseDifferenceMoment_Texture_...    -0.984246
# 5086182  Cytoplasm_Texture_InverseDifferenceMoment_Text...    -0.984253
# 5086216  Cytoplasm_Texture_DifferenceEntropy_Texture_Di...    -0.984951
# 5086269  Cytoplasm_Texture_DifferenceEntropy_Texture_Di...    -0.985737
# 5086295  Cytoplasm_Texture_DifferenceEntropy_Texture_Di...    -0.986061
#
#         Compartment_1                Feature_1_1              Feature_2_1  \
# 0           Cytoplasm   AreaShapeBoundingBoxArea                     None
# 3               Cells  AreaShapeMaxFeretDiameter                     None
# 7           Cytoplasm  AreaShapeMinFeretDiameter                     None
# 8           Cytoplasm                  Intensity         MinIntensityEdge
# 9           Cytoplasm               NumberObject                     None
# ...               ...                        ...                      ...
# 5086181     Cytoplasm                    Texture        DifferenceEntropy
# 5086182         Cells                    Texture               SumEntropy
# 5086216         Cells                    Texture  InverseDifferenceMoment
# 5086269         Cells                    Texture  InverseDifferenceMoment
# 5086295         Cells                    Texture  InverseDifferenceMoment
#
#         Feature_3_1 Channel_1  Suffix_1 Compartment_2  \
# 0              None                             Cells
# 3              None                         Cytoplasm
# 7              None                             Cells
# 8              None       DNA                   Cells
# 9              None              Number        Nuclei
# ...             ...       ...       ...           ...
# 5086181        None       AGP  3_01_256         Cells
# 5086182        None       DNA  3_01_256     Cytoplasm
# 5086216        None       AGP  3_00_256     Cytoplasm
# 5086269        None       AGP  3_00_256     Cytoplasm
# 5086295        None       AGP  3_02_256     Cytoplasm
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 0         AreaShapeBoundingBoxArea                     None        None
# 3        AreaShapeMaxFeretDiameter                     None        None
# 7        AreaShapeMinFeretDiameter                     None        None
# 8                        Intensity         MinIntensityEdge        None
# 9                     NumberObject                     None        None
# ...                            ...                      ...         ...
# 5086181                    Texture  InverseDifferenceMoment        None
# 5086182                    Texture  InverseDifferenceMoment        None
# 5086216                    Texture        DifferenceEntropy        None
# 5086269                    Texture        DifferenceEntropy        None
# 5086295                    Texture        DifferenceEntropy        None
#
#         Channel_2  Suffix_2
# 0
# 3
# 7
# 8             DNA
# 9                    Number
# ...           ...       ...
# 5086181       AGP  3_01_256
# 5086182       DNA  5_01_256
# 5086216       AGP  5_00_256
# 5086269       AGP  3_00_256
# 5086295       AGP  3_02_256
#
# [3389983 rows x 15 columns]

# %%
# Drop correlations between same Feature_1 features

correlation_df_stacked = correlation_df_stacked.query("Feature_1_1!=Feature_1_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 13       Nuclei_ParentNucleiIncludingEdges_ParentNuclei...
# 7499     Cells_Intensity_MeanIntensity_Intensity_MeanIn...
# 7523     Cells_Intensity_MeanIntensity_Intensity_MeanIn...
# 7632     Cells_Intensity_MeanIntensity_Intensity_MeanIn...
# 7643     Cells_Intensity_MedianIntensity_Intensity_Medi...
# ...                                                    ...
# 5079083  Nuclei_Texture_InfoMeas1_Texture_InfoMeas1_RNA...
# 5080829  Nuclei_Texture_InfoMeas1_Texture_InfoMeas1_DNA...
# 5080867  Nuclei_Texture_InfoMeas1_Texture_InfoMeas1_DNA...
# 5080909  Nuclei_Texture_InfoMeas1_Texture_InfoMeas1_DNA...
# 5081022  Nuclei_Texture_InfoMeas1_Texture_InfoMeas1_DNA...
#
#                                             feature_name_2  correlation  \
# 13       Cells_ParentCellsIncludingEdges_ParentCellsInc...     1.000000
# 7499     Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.993355
# 7523     Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.993325
# 7632     Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.993194
# 7643     Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.993175
# ...                                                    ...          ...
# 5079083  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.936294
# 5080829  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.948157
# 5080867  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.948325
# 5080909  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.948594
# 5081022  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.949435
#
#         Compartment_1                 Feature_1_1      Feature_2_1  \
# 13             Nuclei  ParentNucleiIncludingEdges             None
# 7499            Cells                   Intensity    MeanIntensity
# 7523            Cells                   Intensity    MeanIntensity
# 7632            Cells                   Intensity    MeanIntensity
# 7643            Cells                   Intensity  MedianIntensity
# ...               ...                         ...              ...
# 5079083        Nuclei                     Texture        InfoMeas1
# 5080829        Nuclei                     Texture        InfoMeas1
# 5080867        Nuclei                     Texture        InfoMeas1
# 5080909        Nuclei                     Texture        InfoMeas1
# 5081022        Nuclei                     Texture        InfoMeas1
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 13             None                              Cells
# 7499           None      Mito                Cytoplasm
# 7523           None      Mito                Cytoplasm
# 7632           None      Mito                Cytoplasm
# 7643           None       AGP                Cytoplasm
# ...             ...       ...        ...           ...
# 5079083        None       RNA   5_01_256         Cells
# 5080829        None       DNA  10_02_256         Cells
# 5080867        None       DNA  10_00_256         Cells
# 5080909        None       DNA   5_01_256         Cells
# 5081022        None       DNA   5_03_256         Cells
#
#                        Feature_1_2   Feature_2_2 Feature_3_2 Channel_2  \
# 13       ParentCellsIncludingEdges          None        None
# 7499                       Texture    SumAverage        None      Mito
# 7523                       Texture    SumAverage        None      Mito
# 7632                       Texture    SumAverage        None      Mito
# 7643                       Texture    SumAverage        None       AGP
# ...                            ...           ...         ...       ...
# 5079083                  Intensity  MaxIntensity        None       RNA
# 5080829                  Intensity  MaxIntensity        None       DNA
# 5080867                  Intensity  MaxIntensity        None       DNA
# 5080909                  Intensity  MaxIntensity        None       DNA
# 5081022                  Intensity  MaxIntensity        None       DNA
#
#           Suffix_2
# 13
# 7499     10_02_256
# 7523     10_01_256
# 7632     10_03_256
# 7643      5_03_256
# ...            ...
# 5079083
# 5080829
# 5080867
# 5080909
# 5081022
#
# [1781939 rows x 15 columns]

# %%
# Drop features with the same Channel names

correlation_df_stacked = correlation_df_stacked.query("Channel_1!=Channel_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 56697    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 56715    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 56717    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 56720    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 56741    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# ...                                                    ...
# 5052493  Cytoplasm_Texture_InverseDifferenceMoment_Text...
# 5054640  Cells_Texture_InverseDifferenceMoment_Texture_...
# 5054905  Cytoplasm_Intensity_UpperQuartileIntensity_Int...
# 5056079  Cytoplasm_Texture_InverseDifferenceMoment_Text...
# 5056631  Cytoplasm_Texture_InverseDifferenceMoment_Text...
#
#                                             feature_name_2  correlation  \
# 56697    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886799
# 56715    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886775
# 56717    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886768
# 56720    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886759
# 56741    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886731
# ...                                                    ...          ...
# 5052493  Cells_Intensity_UpperQuartileIntensity_Intensi...    -0.823941
# 5054640  Cytoplasm_Intensity_UpperQuartileIntensity_Int...    -0.829478
# 5054905  Cells_Texture_InverseDifferenceMoment_Texture_...    -0.830197
# 5056079  Cells_Intensity_UpperQuartileIntensity_Intensi...    -0.833333
# 5056631  Cells_Intensity_UpperQuartileIntensity_Intensi...    -0.834789
#
#         Compartment_1 Feature_1_1              Feature_2_1 Feature_3_1  \
# 56697          Nuclei     Texture               SumAverage        None
# 56715          Nuclei     Texture               SumAverage        None
# 56717          Nuclei     Texture               SumAverage        None
# 56720          Nuclei     Texture               SumAverage        None
# 56741          Nuclei     Texture               SumAverage        None
# ...               ...         ...                      ...         ...
# 5052493     Cytoplasm     Texture  InverseDifferenceMoment        None
# 5054640         Cells     Texture  InverseDifferenceMoment        None
# 5054905     Cytoplasm   Intensity   UpperQuartileIntensity        None
# 5056079     Cytoplasm     Texture  InverseDifferenceMoment        None
# 5056631     Cytoplasm     Texture  InverseDifferenceMoment        None
#
#         Channel_1  Suffix_1 Compartment_2 Feature_1_2  \
# 56697          ER  5_02_256         Cells   Intensity
# 56715          ER  3_03_256         Cells   Intensity
# 56717          ER  3_01_256         Cells   Intensity
# 56720          ER  5_00_256         Cells   Intensity
# 56741          ER  5_01_256         Cells   Intensity
# ...           ...       ...           ...         ...
# 5052493       RNA  3_03_256         Cells   Intensity
# 5054640       RNA  3_00_256     Cytoplasm   Intensity
# 5054905        ER                   Cells     Texture
# 5056079       RNA  3_00_256         Cells   Intensity
# 5056631       RNA  3_02_256         Cells   Intensity
#
#                      Feature_2_2 Feature_3_2 Channel_2  Suffix_2
# 56697               StdIntensity        None       RNA
# 56715               StdIntensity        None       RNA
# 56717               StdIntensity        None       RNA
# 56720               StdIntensity        None       RNA
# 56741               StdIntensity        None       RNA
# ...                          ...         ...       ...       ...
# 5052493   UpperQuartileIntensity        None        ER
# 5054640   UpperQuartileIntensity        None        ER
# 5054905  InverseDifferenceMoment        None       RNA  3_02_256
# 5056079   UpperQuartileIntensity        None        ER
# 5056631   UpperQuartileIntensity        None        ER
#
# [1535070 rows x 15 columns]

# %%
# Compute absolute correlation

correlation_df_stacked = correlation_df_stacked.assign(
    abs_correlation=lambda x: np.abs(x["correlation"])
)

correlation_df_stacked.sort_values(by=["abs_correlation"], ascending=False, inplace=True)

# %%
# Drop Duplicates

correlation_df_stacked = correlation_df_stacked.drop_duplicates(
    subset=["Feature_1_1", "Feature_1_2", "Feature_2_1", "Feature_2_2"], keep="first"
)

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 56697    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 70495    Cytoplasm_Intensity_StdIntensityEdge_Intensity...
# 72669    Cytoplasm_Texture_SumAverage_Texture_SumAverag...
# 72684    Cells_Intensity_MedianIntensity_Intensity_Medi...
# 74068    Cytoplasm_Intensity_MaxIntensityEdge_Intensity...
# ...                                                    ...
# 3013744  Nuclei_ObjectSkeletonNumberBranchEnds_ObjectSk...
# 2765451          Cytoplasm_Granularity_6_Granularity_6_DNA
# 2975979  Cells_ParentCellsIncludingEdges_ParentCellsInc...
# 2962349  Nuclei_ObjectSkeletonNumberBranchEnds_ObjectSk...
# 2816951  Nuclei_ObjectSkeletonNumberTrunks_ObjectSkelet...
#
#                                             feature_name_2  correlation  \
# 56697    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886799
# 70495    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.866521
# 72669    Cells_Intensity_MedianIntensity_Intensity_Medi...     0.863276
# 72684    Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.863254
# 74068    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.861236
# ...                                                    ...          ...
# 3013744              Cells_Granularity_3_Granularity_3_DNA    -0.008282
# 2765451  Nuclei_ParentNucleiIncludingEdges_ParentNuclei...     0.007230
# 2975979  Nuclei_Location_CenterMassIntensity_Y_Location...    -0.005230
# 2962349  Cytoplasm_Intensity_StdIntensityEdge_Intensity...    -0.004236
# 2816951  Cells_Intensity_MinIntensity_Intensity_MinInte...     0.004085
#
#         Compartment_1                     Feature_1_1       Feature_2_1  \
# 56697          Nuclei                         Texture        SumAverage
# 70495       Cytoplasm                       Intensity  StdIntensityEdge
# 72669       Cytoplasm                         Texture        SumAverage
# 72684           Cells                       Intensity   MedianIntensity
# 74068       Cytoplasm                       Intensity  MaxIntensityEdge
# ...               ...                             ...               ...
# 3013744        Nuclei  ObjectSkeletonNumberBranchEnds              None
# 2765451     Cytoplasm                     Granularity                 6
# 2975979         Cells       ParentCellsIncludingEdges              None
# 2962349        Nuclei  ObjectSkeletonNumberBranchEnds              None
# 2816951        Nuclei      ObjectSkeletonNumberTrunks              None
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 56697          None        ER   5_02_256         Cells
# 70495          None       RNA                   Nuclei
# 72669          None        ER   3_02_256         Cells
# 72684          None       RNA                Cytoplasm
# 74068          None       RNA                   Nuclei
# ...             ...       ...        ...           ...
# 3013744        None            mito_skel         Cells
# 2765451        None       DNA                   Nuclei
# 2975979        None                             Nuclei
# 2962349        None            mito_skel     Cytoplasm
# 2816951        None            mito_skel         Cells
#
#                         Feature_1_2          Feature_2_2 Feature_3_2  \
# 56697                     Intensity         StdIntensity        None
# 70495                       Texture           SumAverage        None
# 72669                     Intensity      MedianIntensity        None
# 72684                       Texture           SumAverage        None
# 74068                       Texture           SumAverage        None
# ...                             ...                  ...         ...
# 3013744                 Granularity                    3        None
# 2765451  ParentNucleiIncludingEdges                 None        None
# 2975979                    Location  CenterMassIntensity           Y
# 2962349                   Intensity     StdIntensityEdge        None
# 2816951                   Intensity         MinIntensity        None
#
#         Channel_2  Suffix_2  abs_correlation
# 56697         RNA                   0.886799
# 70495          ER  3_00_256         0.866521
# 72669         RNA                   0.863276
# 72684          ER  3_00_256         0.863254
# 74068          ER  3_00_256         0.861236
# ...           ...       ...              ...
# 3013744       DNA                   0.008282
# 2765451                             0.007230
# 2975979        ER                   0.005230
# 2962349        ER                   0.004236
# 2816951       RNA                   0.004085
#
# [4949 rows x 16 columns]

# %%
# Keep only highly correlated features

correlation_df_stacked.sort_values(by=["correlation"], ascending=False, inplace=True)
correlation_df_stacked = correlation_df_stacked.query("correlation>0.8 or correlation<-0.8")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 56697    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 70495    Cytoplasm_Intensity_StdIntensityEdge_Intensity...
# 72669    Cytoplasm_Texture_SumAverage_Texture_SumAverag...
# 72684    Cells_Intensity_MedianIntensity_Intensity_Medi...
# 74068    Cytoplasm_Intensity_MaxIntensityEdge_Intensity...
# 74557    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 75322    Cells_Intensity_StdIntensityEdge_Intensity_Std...
# 81727    Cytoplasm_Intensity_MaxIntensity_Intensity_Max...
# 82166    Nuclei_Texture_SumAverage_Texture_SumAverage_E...
# 82322    Cytoplasm_Intensity_StdIntensity_Intensity_Std...
# 84640    Nuclei_Intensity_MeanIntensity_Intensity_MeanI...
# 85151    Cells_Texture_DifferenceEntropy_Texture_Differ...
# 85512    Cytoplasm_Intensity_MeanIntensity_Intensity_Me...
# 85604    Nuclei_Intensity_MedianIntensity_Intensity_Med...
# 85708                Cells_Granularity_2_Granularity_2_RNA
# 86391    Cytoplasm_Texture_SumAverage_Texture_SumAverag...
# 86797    Cells_Texture_DifferenceEntropy_Texture_Differ...
# 87341    Cells_Texture_DifferenceEntropy_Texture_Differ...
# 87572    Nuclei_Intensity_UpperQuartileIntensity_Intens...
# 87821    Cells_Texture_DifferenceEntropy_Texture_Differ...
# 90877    Cells_Texture_SumEntropy_Texture_SumEntropy_RN...
# 92142            Cytoplasm_Granularity_1_Granularity_1_AGP
# 93218    Cells_Texture_SumAverage_Texture_SumAverage_ER...
# 93265    Cytoplasm_Intensity_UpperQuartileIntensity_Int...
# 96062    Nuclei_Intensity_MedianIntensity_Intensity_Med...
# 96552    Nuclei_Intensity_MeanIntensity_Intensity_MeanI...
# 96998    Cells_Texture_SumEntropy_Texture_SumEntropy_RN...
# 97576    Cells_Texture_SumEntropy_Texture_SumEntropy_RN...
# 98031    Cells_Intensity_StdIntensityEdge_Intensity_Std...
# 99747    Cytoplasm_Texture_DifferenceEntropy_Texture_Di...
# 101480   Cells_Intensity_MADIntensity_Intensity_MADInte...
# 103935   Nuclei_RadialDistribution_RadialCV_RadialDistr...
# 104043   Nuclei_Intensity_UpperQuartileIntensity_Intens...
# 105097   Cells_Texture_SumEntropy_Texture_SumEntropy_RN...
# 110097   Cells_Intensity_MaxIntensityEdge_Intensity_Max...
# 111442   Cells_Texture_SumAverage_Texture_SumAverage_RN...
# 113135   Cells_Intensity_MaxIntensityEdge_Intensity_Max...
# 114974   Nuclei_Intensity_UpperQuartileIntensity_Intens...
# 115341   Cytoplasm_Intensity_MeanIntensityEdge_Intensit...
# 115824   Cells_Texture_SumVariance_Texture_SumVariance_...
# 116575   Cells_Texture_Entropy_Texture_Entropy_RNA_10_0...
# 116754   Cells_Texture_Variance_Texture_Variance_RNA_3_...
# 116783   Nuclei_Intensity_UpperQuartileIntensity_Intens...
# 117563   Nuclei_Intensity_MedianIntensity_Intensity_Med...
# 119038   Cells_Texture_SumVariance_Texture_SumVariance_...
# 120234   Cytoplasm_Texture_Entropy_Texture_Entropy_RNA_...
# 121108   Cells_Texture_Variance_Texture_Variance_RNA_3_...
# 121130   Nuclei_Intensity_MedianIntensity_Intensity_Med...
# 5044609  Cytoplasm_Texture_InverseDifferenceMoment_Text...
# 5048061  Nuclei_RadialDistribution_MeanFrac_RadialDistr...
# 5048667  Cells_RadialDistributionRadialCV_RadialDistrib...
# 5052012  Cells_Intensity_MeanIntensity_Intensity_MeanIn...
# 5054905  Cytoplasm_Intensity_UpperQuartileIntensity_Int...
# 5056631  Cytoplasm_Texture_InverseDifferenceMoment_Text...
#
#                                             feature_name_2  correlation  \
# 56697    Cells_Intensity_StdIntensity_Intensity_StdInte...     0.886799
# 70495    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.866521
# 72669    Cells_Intensity_MedianIntensity_Intensity_Medi...     0.863276
# 72684    Cytoplasm_Texture_SumAverage_Texture_SumAverag...     0.863254
# 74068    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.861236
# 74557    Cytoplasm_Intensity_MaxIntensityEdge_Intensity...     0.860571
# 75322    Nuclei_NeighborsPercentTouching_NeighborsPerce...     0.859516
# 81727    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.850700
# 82166    Cytoplasm_Intensity_MaxIntensity_Intensity_Max...     0.850080
# 82322    Nuclei_Texture_SumAverage_Texture_SumAverage_E...     0.849870
# 84640    Cells_Texture_DifferenceEntropy_Texture_Differ...     0.846977
# 85151    Nuclei_Intensity_MeanIntensity_Intensity_MeanI...     0.846269
# 85512    Cells_Texture_SumAverage_Texture_SumAverage_RN...     0.845748
# 85604    Cells_Texture_DifferenceEntropy_Texture_Differ...     0.845612
# 85708    Nuclei_RadialDistribution_RadialCV_RadialDistr...     0.845469
# 86391    Cells_Intensity_MeanIntensity_Intensity_MeanIn...     0.844530
# 86797    Nuclei_Intensity_MedianIntensity_Intensity_Med...     0.843977
# 87341    Nuclei_Intensity_LowerQuartileIntensity_Intens...     0.843187
# 87572    Cells_Texture_DifferenceEntropy_Texture_Differ...     0.842854
# 87821    Nuclei_Intensity_UpperQuartileIntensity_Intens...     0.842538
# 90877    Nuclei_Intensity_LowerQuartileIntensity_Intens...     0.838515
# 92142    Cells_NeighborsPercentTouching_NeighborsPercen...     0.836713
# 93218    Cytoplasm_Intensity_UpperQuartileIntensity_Int...     0.835072
# 93265    Cells_Texture_SumAverage_Texture_SumAverage_ER...     0.835005
# 96062    Cells_Texture_SumEntropy_Texture_SumEntropy_RN...     0.831051
# 96552    Cells_Texture_SumEntropy_Texture_SumEntropy_RN...     0.830385
# 96998    Nuclei_Intensity_MedianIntensity_Intensity_Med...     0.829766
# 97576    Nuclei_Intensity_MeanIntensity_Intensity_MeanI...     0.828965
# 98031    Nuclei_NeighborsNumberOfNeighbors_NeighborsNum...     0.828462
# 99747    Cells_Intensity_MADIntensity_Intensity_MADInte...     0.826336
# 101480   Cytoplasm_Texture_DifferenceEntropy_Texture_Di...     0.824303
# 103935               Cells_Granularity_2_Granularity_2_RNA     0.821567
# 104043   Cells_Texture_SumEntropy_Texture_SumEntropy_RN...     0.821446
# 105097   Nuclei_Intensity_UpperQuartileIntensity_Intens...     0.820206
# 110097   Nuclei_NeighborsPercentTouching_NeighborsPerce...     0.814723
# 111442   Cytoplasm_Intensity_MeanIntensityEdge_Intensit...     0.813273
# 113135   Nuclei_NeighborsNumberOfNeighbors_NeighborsNum...     0.811406
# 114974   Cells_Texture_SumVariance_Texture_SumVariance_...     0.809328
# 115341   Cells_Texture_SumAverage_Texture_SumAverage_RN...     0.808910
# 115824   Nuclei_Intensity_UpperQuartileIntensity_Intens...     0.808354
# 116575   Nuclei_Intensity_LowerQuartileIntensity_Intens...     0.807456
# 116754   Nuclei_Intensity_UpperQuartileIntensity_Intens...     0.807221
# 116783   Cells_Texture_Variance_Texture_Variance_RNA_3_...     0.807196
# 117563   Cells_Texture_SumVariance_Texture_SumVariance_...     0.806267
# 119038   Nuclei_Intensity_MedianIntensity_Intensity_Med...     0.804464
# 120234   Cells_Intensity_UpperQuartileIntensity_Intensi...     0.803031
# 121108   Nuclei_Intensity_MedianIntensity_Intensity_Med...     0.801990
# 121130   Cells_Texture_Variance_Texture_Variance_RNA_3_...     0.801965
# 5044609  Cells_Intensity_MADIntensity_Intensity_MADInte...    -0.803444
# 5048061  Cells_RadialDistributionRadialCV_RadialDistrib...    -0.812469
# 5048667  Nuclei_RadialDistribution_MeanFrac_RadialDistr...    -0.813959
# 5052012  Cytoplasm_Texture_InverseDifferenceMoment_Text...    -0.822751
# 5054905  Cells_Texture_InverseDifferenceMoment_Texture_...    -0.830197
# 5056631  Cells_Intensity_UpperQuartileIntensity_Intensi...    -0.834789
#
#         Compartment_1                 Feature_1_1              Feature_2_1  \
# 56697          Nuclei                     Texture               SumAverage
# 70495       Cytoplasm                   Intensity         StdIntensityEdge
# 72669       Cytoplasm                     Texture               SumAverage
# 72684           Cells                   Intensity          MedianIntensity
# 74068       Cytoplasm                   Intensity         MaxIntensityEdge
# 74557          Nuclei                     Texture               SumAverage
# 75322           Cells                   Intensity         StdIntensityEdge
# 81727       Cytoplasm                   Intensity             MaxIntensity
# 82166          Nuclei                     Texture               SumAverage
# 82322       Cytoplasm                   Intensity             StdIntensity
# 84640          Nuclei                   Intensity            MeanIntensity
# 85151           Cells                     Texture        DifferenceEntropy
# 85512       Cytoplasm                   Intensity            MeanIntensity
# 85604          Nuclei                   Intensity          MedianIntensity
# 85708           Cells                 Granularity                        2
# 86391       Cytoplasm                     Texture               SumAverage
# 86797           Cells                     Texture        DifferenceEntropy
# 87341           Cells                     Texture        DifferenceEntropy
# 87572          Nuclei                   Intensity   UpperQuartileIntensity
# 87821           Cells                     Texture        DifferenceEntropy
# 90877           Cells                     Texture               SumEntropy
# 92142       Cytoplasm                 Granularity                        1
# 93218           Cells                     Texture               SumAverage
# 93265       Cytoplasm                   Intensity   UpperQuartileIntensity
# 96062          Nuclei                   Intensity          MedianIntensity
# 96552          Nuclei                   Intensity            MeanIntensity
# 96998           Cells                     Texture               SumEntropy
# 97576           Cells                     Texture               SumEntropy
# 98031           Cells                   Intensity         StdIntensityEdge
# 99747       Cytoplasm                     Texture        DifferenceEntropy
# 101480          Cells                   Intensity             MADIntensity
# 103935         Nuclei          RadialDistribution                 RadialCV
# 104043         Nuclei                   Intensity   UpperQuartileIntensity
# 105097          Cells                     Texture               SumEntropy
# 110097          Cells                   Intensity         MaxIntensityEdge
# 111442          Cells                     Texture               SumAverage
# 113135          Cells                   Intensity         MaxIntensityEdge
# 114974         Nuclei                   Intensity   UpperQuartileIntensity
# 115341      Cytoplasm                   Intensity        MeanIntensityEdge
# 115824          Cells                     Texture              SumVariance
# 116575          Cells                     Texture                  Entropy
# 116754          Cells                     Texture                 Variance
# 116783         Nuclei                   Intensity   UpperQuartileIntensity
# 117563         Nuclei                   Intensity          MedianIntensity
# 119038          Cells                     Texture              SumVariance
# 120234      Cytoplasm                     Texture                  Entropy
# 121108          Cells                     Texture                 Variance
# 121130         Nuclei                   Intensity          MedianIntensity
# 5044609     Cytoplasm                     Texture  InverseDifferenceMoment
# 5048061        Nuclei          RadialDistribution                 MeanFrac
# 5048667         Cells  RadialDistributionRadialCV                     None
# 5052012         Cells                   Intensity            MeanIntensity
# 5054905     Cytoplasm                   Intensity   UpperQuartileIntensity
# 5056631     Cytoplasm                     Texture  InverseDifferenceMoment
#
#         Feature_3_1 Channel_1             Suffix_1 Compartment_2  \
# 56697          None        ER             5_02_256         Cells
# 70495          None       RNA                             Nuclei
# 72669          None        ER             3_02_256         Cells
# 72684          None       RNA                          Cytoplasm
# 74068          None       RNA                             Nuclei
# 74557          None        ER            10_03_256     Cytoplasm
# 75322          None       DNA                             Nuclei
# 81727          None       RNA                             Nuclei
# 82166          None        ER             3_03_256     Cytoplasm
# 82322          None       RNA                             Nuclei
# 84640          None        ER                              Cells
# 85151          None       RNA            10_02_256        Nuclei
# 85512          None        ER                              Cells
# 85604          None        ER                              Cells
# 85708          None       RNA                             Nuclei
# 86391          None        ER             3_02_256         Cells
# 86797          None       RNA            10_02_256        Nuclei
# 87341          None       RNA            10_03_256        Nuclei
# 87572          None        ER                              Cells
# 87821          None       RNA            10_02_256        Nuclei
# 90877          None       RNA            10_01_256        Nuclei
# 92142          None       AGP                              Cells
# 93218          None        ER             3_00_256     Cytoplasm
# 93265          None       RNA                              Cells
# 96062          None        ER                              Cells
# 96552          None        ER                              Cells
# 96998          None       RNA            10_02_256        Nuclei
# 97576          None       RNA            10_02_256        Nuclei
# 98031          None       DNA                             Nuclei
# 99747          None       RNA             5_02_256         Cells
# 101480         None        ER                          Cytoplasm
# 103935         None        ER                 1of4         Cells
# 104043         None        ER                              Cells
# 105097         None       RNA            10_02_256        Nuclei
# 110097         None       DNA                             Nuclei
# 111442         None       RNA             3_02_256     Cytoplasm
# 113135         None       DNA                             Nuclei
# 114974         None        ER                              Cells
# 115341         None        ER                              Cells
# 115824         None       RNA            10_02_256        Nuclei
# 116575         None       RNA            10_00_256        Nuclei
# 116754         None       RNA             3_02_256        Nuclei
# 116783         None        ER                              Cells
# 117563         None        ER                              Cells
# 119038         None       RNA            10_02_256        Nuclei
# 120234         None       RNA             3_02_256         Cells
# 121108         None       RNA             3_02_256        Nuclei
# 121130         None        ER                              Cells
# 5044609        None       RNA             3_02_256         Cells
# 5048061        None      Mito                 3of4         Cells
# 5048667        None            mito_tubeness_7of16        Nuclei
# 5052012        None        ER                          Cytoplasm
# 5054905        None        ER                              Cells
# 5056631        None       RNA             3_02_256         Cells
#
#                         Feature_1_2              Feature_2_2 Feature_3_2  \
# 56697                     Intensity             StdIntensity        None
# 70495                       Texture               SumAverage        None
# 72669                     Intensity          MedianIntensity        None
# 72684                       Texture               SumAverage        None
# 74068                       Texture               SumAverage        None
# 74557                     Intensity         MaxIntensityEdge        None
# 75322      NeighborsPercentTouching                     None        None
# 81727                       Texture               SumAverage        None
# 82166                     Intensity             MaxIntensity        None
# 82322                       Texture               SumAverage        None
# 84640                       Texture        DifferenceEntropy        None
# 85151                     Intensity            MeanIntensity        None
# 85512                       Texture               SumAverage        None
# 85604                       Texture        DifferenceEntropy        None
# 85708            RadialDistribution                 RadialCV        None
# 86391                     Intensity            MeanIntensity        None
# 86797                     Intensity          MedianIntensity        None
# 87341                     Intensity   LowerQuartileIntensity        None
# 87572                       Texture        DifferenceEntropy        None
# 87821                     Intensity   UpperQuartileIntensity        None
# 90877                     Intensity   LowerQuartileIntensity        None
# 92142      NeighborsPercentTouching                     None        None
# 93218                     Intensity   UpperQuartileIntensity        None
# 93265                       Texture               SumAverage        None
# 96062                       Texture               SumEntropy        None
# 96552                       Texture               SumEntropy        None
# 96998                     Intensity          MedianIntensity        None
# 97576                     Intensity            MeanIntensity        None
# 98031    NeighborsNumberOfNeighbors                     None        None
# 99747                     Intensity             MADIntensity        None
# 101480                      Texture        DifferenceEntropy        None
# 103935                  Granularity                        2        None
# 104043                      Texture               SumEntropy        None
# 105097                    Intensity   UpperQuartileIntensity        None
# 110097     NeighborsPercentTouching                     None        None
# 111442                    Intensity        MeanIntensityEdge        None
# 113135   NeighborsNumberOfNeighbors                     None        None
# 114974                      Texture              SumVariance        None
# 115341                      Texture               SumAverage        None
# 115824                    Intensity   UpperQuartileIntensity        None
# 116575                    Intensity   LowerQuartileIntensity        None
# 116754                    Intensity   UpperQuartileIntensity        None
# 116783                      Texture                 Variance        None
# 117563                      Texture              SumVariance        None
# 119038                    Intensity          MedianIntensity        None
# 120234                    Intensity   UpperQuartileIntensity        None
# 121108                    Intensity          MedianIntensity        None
# 121130                      Texture                 Variance        None
# 5044609                   Intensity             MADIntensity        None
# 5048061  RadialDistributionRadialCV                     None        None
# 5048667          RadialDistribution                 MeanFrac        None
# 5052012                     Texture  InverseDifferenceMoment        None
# 5054905                     Texture  InverseDifferenceMoment        None
# 5056631                   Intensity   UpperQuartileIntensity        None
#
#         Channel_2             Suffix_2  abs_correlation
# 56697         RNA                              0.886799
# 70495          ER             3_00_256         0.866521
# 72669         RNA                              0.863276
# 72684          ER             3_00_256         0.863254
# 74068          ER             3_00_256         0.861236
# 74557         RNA                              0.860571
# 75322                                1         0.859516
# 81727          ER             3_00_256         0.850700
# 82166         RNA                              0.850080
# 82322          ER             3_00_256         0.849870
# 84640         RNA            10_03_256         0.846977
# 85151          ER                              0.846269
# 85512         RNA             3_02_256         0.845748
# 85604         RNA            10_03_256         0.845612
# 85708          ER                 2of4         0.845469
# 86391         RNA                              0.844530
# 86797          ER                              0.843977
# 87341          ER                              0.843187
# 87572         RNA            10_03_256         0.842854
# 87821          ER                              0.842538
# 90877          ER                              0.838515
# 92142                                5         0.836713
# 93218         RNA                              0.835072
# 93265          ER             3_02_256         0.835005
# 96062         RNA            10_01_256         0.831051
# 96552         RNA            10_01_256         0.830385
# 96998          ER                              0.829766
# 97576          ER                              0.828965
# 98031                                1         0.828462
# 99747          ER                              0.826336
# 101480        RNA             3_01_256         0.824303
# 103935        RNA                              0.821567
# 104043        RNA            10_01_256         0.821446
# 105097         ER                              0.820206
# 110097                               1         0.814723
# 111442         ER                              0.813273
# 113135                               1         0.811406
# 114974        RNA            10_01_256         0.809328
# 115341        RNA             5_02_256         0.808910
# 115824         ER                              0.808354
# 116575         ER                              0.807456
# 116754         ER                              0.807221
# 116783        RNA             3_00_256         0.807196
# 117563        RNA            10_01_256         0.806267
# 119038         ER                              0.804464
# 120234         ER                              0.803031
# 121108         ER                              0.801990
# 121130        RNA             3_00_256         0.801965
# 5044609        ER                              0.803444
# 5048061            mito_tubeness_8of20         0.812469
# 5048667      Mito                 3of4         0.813959
# 5052012       RNA             3_02_256         0.822751
# 5054905       RNA             3_02_256         0.830197
# 5056631        ER                              0.834789

# %%
correlation_df_stacked[["feature_name_1", "feature_name_2", "correlation"]].to_csv('output/orf_top_correlations.csv', index=False)
