# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %% [markdown]
# Rules
# - Drop Correlation features
# - Drop Object Number features
# - Drop features with X,Y suffix
# - Drop correlations between same compartment features
# - Drop correlations between same Feature categories
# - Keep only one row per feature group
# - Keep only highly correlated/anticorrelated features

# %%
feature_name_cols = ["Compartment", "Feature", "Feature_1", "Feature_2", "Feature_3", "Channel", "Suffix"]

# %%
crispr_feature_df = pd.read_parquet("input/crispr_feature_wide.parquet").rename(
    columns={"Mask": "Compartment"}
)

# Split Feature further
crispr_feature_df[["Feature_1", "Feature_2", "Feature_3"]] = (
    crispr_feature_df.Feature.str.split("_", expand=True)
)

# Remove leading underscore from column values

crispr_feature_df["Suffix"] = crispr_feature_df["Suffix"].apply(lambda x: x.lstrip("_"))

# Create feature name
crispr_feature_df["feature_name"] = crispr_feature_df[["Compartment", "Feature_1", "Feature_2", "Feature_3", "Channel", "Suffix"]].agg(
    lambda x: "_".join(filter(None, x)), axis=1
)

crispr_feature_df.head()
# Out:
#   Compartment                     Feature Channel     Suffix  column_0  \
# 0       Cells         Texture_Correlation      ER  10_02_256  1.000000
# 1   Cytoplasm    AreaShapeBoundingBoxArea                     0.507748
# 2   Cytoplasm  Intensity_MassDisplacement     RNA             0.606947
# 3   Cytoplasm            Texture_Contrast     DNA  10_02_256  0.002188
# 4   Cytoplasm         Texture_Correlation    Mito  10_01_256  0.486636
#
#    column_1  column_2  column_3  column_4  column_5  ...  column_3645  \
# 0  0.507748  0.606947  0.002188  0.486636  0.603111  ...     0.176715
# 1  1.000000  0.785837 -0.001925  0.575591  0.294705  ...     0.054823
# 2  0.785837  1.000000  0.002393  0.549004  0.280987  ...     0.191329
# 3 -0.001925  0.002393  1.000000 -0.002864 -0.002334  ...     0.005742
# 4  0.575591  0.549004 -0.002864  1.000000  0.478242  ...     0.048198
#
#    column_3646  column_3647  column_3648  column_3649  column_3650  \
# 0     0.463619    -0.301220     0.039268     0.203778     0.043879
# 1    -0.145195    -0.243519    -0.059198     0.125026    -0.160831
# 2    -0.130523    -0.461357     0.196529     0.190383     0.022665
# 3     0.005219    -0.001404     0.008478    -0.000910     0.087698
# 4     0.003907    -0.157372     0.046812     0.083500    -0.040116
#
#                   Feature_1         Feature_2  Feature_3  \
# 0                   Texture       Correlation       None
# 1  AreaShapeBoundingBoxArea              None       None
# 2                 Intensity  MassDisplacement       None
# 3                   Texture          Contrast       None
# 4                   Texture       Correlation       None
#
#                                    feature_name
# 0        Cells_Texture_Correlation_ER_10_02_256
# 1            Cytoplasm_AreaShapeBoundingBoxArea
# 2      Cytoplasm_Intensity_MassDisplacement_RNA
# 3      Cytoplasm_Texture_Contrast_DNA_10_02_256
# 4  Cytoplasm_Texture_Correlation_Mito_10_01_256
#
# [5 rows x 3659 columns]

# %%
# Rename column names 

feature_names_df = crispr_feature_df[feature_name_cols + ["feature_name"]].copy()
correlation_df = crispr_feature_df.drop(columns=feature_name_cols).set_index("feature_name")
correlation_df.columns = feature_names_df.feature_name.to_list()

# %%
# Remove Correlation features
feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Correlation")
]

# Remove Object Number features

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("ObjectNumber")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Object_Number")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("X")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("Y")
]


correlation_df = correlation_df.loc[
    feature_names_df.feature_name.to_list(), feature_names_df.feature_name.to_list()
]

# %%
# Stack the dataframe

correlation_df_stacked = (
    correlation_df.mask(np.tril(np.ones(correlation_df.shape)).astype(bool))
    .stack()
    .reset_index()
    .rename(
        columns={
            0: "correlation",
            "feature_name": "feature_name_1",
            "level_1": "feature_name_2",
        }
    )
).sort_values(by=["correlation"], ascending=False)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 1821117       Cells_NeighborsFirstClosestDistance_Adjacent
# 4809812      Cells_NeighborsSecondClosestDistance_Adjacent
# 5055090             Cells_NeighborsAngleBetweenNeighbors_5
# 3356164  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 871324   Cytoplasm_RadialDistributionMeanFrac_mito_tube...
# ...                                                    ...
# 2977468  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 820909   Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 3166497  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 2640397  Cytoplasm_RadialDistributionMeanFrac_mito_tube...
# 2977707  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
#
#                                             feature_name_2  correlation
# 1821117              Cells_NeighborsFirstClosestDistance_5     1.000000
# 4809812             Cells_NeighborsSecondClosestDistance_5     1.000000
# 5055090      Cells_NeighborsAngleBetweenNeighbors_Adjacent     1.000000
# 3356164  Cytoplasm_RadialDistributionFracAtD_mito_tuben...     1.000000
# 871324   Cytoplasm_RadialDistributionMeanFrac_mito_tube...     1.000000
# ...                                                    ...          ...
# 2977468  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997748
# 820909   Cytoplasm_RadialDistributionFracAtD_mito_tuben...    -0.997794
# 3166497  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997799
# 2640397  Cytoplasm_RadialDistributionFracAtD_mito_tuben...    -0.997951
# 2977707  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997961
#
# [5134410 rows x 3 columns]

# %%
# Add other feature name columns

correlation_df_stacked = (
    correlation_df_stacked.merge(
        feature_names_df, left_on="feature_name_1", right_on="feature_name", how="left"
    )
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_1",
            "Channel": "Channel_1",
            "Suffix": "Suffix_1",
            "Feature_1": "Feature_1_1",
            "Feature_2": "Feature_2_1",
            "Feature_3": "Feature_3_1",
        }
    )
    .merge(feature_names_df, left_on="feature_name_2", right_on="feature_name", how="left")
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_2",
            "Channel": "Channel_2",
            "Suffix": "Suffix_2",
            "Feature_1": "Feature_1_2",
            "Feature_2": "Feature_2_2",
            "Feature_3": "Feature_3_2",
        }
    )
)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 0             Cells_NeighborsFirstClosestDistance_Adjacent
# 1            Cells_NeighborsSecondClosestDistance_Adjacent
# 2                   Cells_NeighborsAngleBetweenNeighbors_5
# 3        Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 4        Cytoplasm_RadialDistributionMeanFrac_mito_tube...
# ...                                                    ...
# 5134405  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 5134406  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 5134407  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
# 5134408  Cytoplasm_RadialDistributionMeanFrac_mito_tube...
# 5134409  Cytoplasm_RadialDistributionFracAtD_mito_tuben...
#
#                                             feature_name_2  correlation  \
# 0                    Cells_NeighborsFirstClosestDistance_5     1.000000
# 1                   Cells_NeighborsSecondClosestDistance_5     1.000000
# 2            Cells_NeighborsAngleBetweenNeighbors_Adjacent     1.000000
# 3        Cytoplasm_RadialDistributionFracAtD_mito_tuben...     1.000000
# 4        Cytoplasm_RadialDistributionMeanFrac_mito_tube...     1.000000
# ...                                                    ...          ...
# 5134405  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997748
# 5134406  Cytoplasm_RadialDistributionFracAtD_mito_tuben...    -0.997794
# 5134407  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997799
# 5134408  Cytoplasm_RadialDistributionFracAtD_mito_tuben...    -0.997951
# 5134409  Cytoplasm_RadialDistributionMeanFrac_mito_tube...    -0.997961
#
#         Compartment_1                     Feature_1_1 Feature_2_1 Feature_3_1  \
# 0               Cells   NeighborsFirstClosestDistance        None        None
# 1               Cells  NeighborsSecondClosestDistance        None        None
# 2               Cells  NeighborsAngleBetweenNeighbors        None        None
# 3           Cytoplasm       RadialDistributionFracAtD        None        None
# 4           Cytoplasm      RadialDistributionMeanFrac        None        None
# ...               ...                             ...         ...         ...
# 5134405     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134406     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134407     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134408     Cytoplasm      RadialDistributionMeanFrac        None        None
# 5134409     Cytoplasm       RadialDistributionFracAtD        None        None
#
#         Channel_1              Suffix_1 Compartment_2  \
# 0                              Adjacent         Cells
# 1                              Adjacent         Cells
# 2                                     5         Cells
# 3                   mito_tubeness_1of20     Cytoplasm
# 4                   mito_tubeness_1of20     Cytoplasm
# ...           ...                   ...           ...
# 5134405            mito_tubeness_20of20     Cytoplasm
# 5134406            mito_tubeness_18of20     Cytoplasm
# 5134407            mito_tubeness_16of16     Cytoplasm
# 5134408            mito_tubeness_17of20     Cytoplasm
# 5134409            mito_tubeness_20of20     Cytoplasm
#
#                             Feature_1_2 Feature_2_2 Feature_3_2 Channel_2  \
# 0         NeighborsFirstClosestDistance        None        None
# 1        NeighborsSecondClosestDistance        None        None
# 2        NeighborsAngleBetweenNeighbors        None        None
# 3             RadialDistributionFracAtD        None        None
# 4            RadialDistributionMeanFrac        None        None
# ...                                 ...         ...         ...       ...
# 5134405      RadialDistributionMeanFrac        None        None
# 5134406       RadialDistributionFracAtD        None        None
# 5134407      RadialDistributionMeanFrac        None        None
# 5134408       RadialDistributionFracAtD        None        None
# 5134409      RadialDistributionMeanFrac        None        None
#
#                      Suffix_2
# 0                           5
# 1                           5
# 2                    Adjacent
# 3         mito_tubeness_1of16
# 4         mito_tubeness_1of16
# ...                       ...
# 5134405  mito_tubeness_18of20
# 5134406  mito_tubeness_16of16
# 5134407  mito_tubeness_14of16
# 5134408  mito_tubeness_16of16
# 5134409  mito_tubeness_14of16
#
# [5134410 rows x 15 columns]

# %%
# Drop correlations between same compartment features

correlation_df_stacked = correlation_df_stacked.query("Compartment_1!=Compartment_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 5                               Nuclei_NumberObject_Number
# 27                         Cells_AreaShapeMinFeretDiameter
# 44                         Cells_AreaShapeMaxFeretDiameter
# 140                     Cytoplasm_AreaShapeBoundingBoxArea
# 735                Cytoplasm_Intensity_MinIntensityEdge_ER
# ...                                                    ...
# 5132443      Cells_Texture_DifferenceEntropy_DNA_10_03_256
# 5132455      Cells_Texture_DifferenceEntropy_DNA_10_03_256
# 5132462      Cells_Texture_DifferenceEntropy_DNA_10_01_256
# 5132598      Cells_Texture_DifferenceEntropy_DNA_10_03_256
# 5132607  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...
#
#                                             feature_name_2  correlation  \
# 5                            Cytoplasm_NumberObject_Number     0.999999
# 27                     Cytoplasm_AreaShapeMinFeretDiameter     0.999984
# 44                     Cytoplasm_AreaShapeMaxFeretDiameter     0.999966
# 140                         Cells_AreaShapeBoundingBoxArea     0.999931
# 735                    Cells_Intensity_MinIntensityEdge_ER     0.999735
# ...                                                    ...          ...
# 5132443  Nuclei_Texture_InverseDifferenceMoment_DNA_3_0...    -0.979870
# 5132455  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...    -0.979962
# 5132462  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...    -0.980010
# 5132598  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...    -0.980713
# 5132607      Cells_Texture_DifferenceEntropy_DNA_10_01_256    -0.980751
#
#         Compartment_1                Feature_1_1              Feature_2_1  \
# 5              Nuclei               NumberObject                     None
# 27              Cells  AreaShapeMinFeretDiameter                     None
# 44              Cells  AreaShapeMaxFeretDiameter                     None
# 140         Cytoplasm   AreaShapeBoundingBoxArea                     None
# 735         Cytoplasm                  Intensity         MinIntensityEdge
# ...               ...                        ...                      ...
# 5132443         Cells                    Texture        DifferenceEntropy
# 5132455         Cells                    Texture        DifferenceEntropy
# 5132462         Cells                    Texture        DifferenceEntropy
# 5132598         Cells                    Texture        DifferenceEntropy
# 5132607        Nuclei                    Texture  InverseDifferenceMoment
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 5              None               Number     Cytoplasm
# 27             None                          Cytoplasm
# 44             None                          Cytoplasm
# 140            None                              Cells
# 735            None        ER                    Cells
# ...             ...       ...        ...           ...
# 5132443        None       DNA  10_03_256        Nuclei
# 5132455        None       DNA  10_03_256        Nuclei
# 5132462        None       DNA  10_01_256        Nuclei
# 5132598        None       DNA  10_03_256        Nuclei
# 5132607        None       DNA   5_01_256         Cells
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 5                     NumberObject                     None        None
# 27       AreaShapeMinFeretDiameter                     None        None
# 44       AreaShapeMaxFeretDiameter                     None        None
# 140       AreaShapeBoundingBoxArea                     None        None
# 735                      Intensity         MinIntensityEdge        None
# ...                            ...                      ...         ...
# 5132443                    Texture  InverseDifferenceMoment        None
# 5132455                    Texture  InverseDifferenceMoment        None
# 5132462                    Texture  InverseDifferenceMoment        None
# 5132598                    Texture  InverseDifferenceMoment        None
# 5132607                    Texture        DifferenceEntropy        None
#
#         Channel_2   Suffix_2
# 5                     Number
# 27
# 44
# 140
# 735            ER
# ...           ...        ...
# 5132443       DNA   3_03_256
# 5132455       DNA   5_01_256
# 5132462       DNA   5_03_256
# 5132598       DNA   5_03_256
# 5132607       DNA  10_01_256
#
# [3421826 rows x 15 columns]

# %%
# Drop correlations between same Feature_1 features

correlation_df_stacked = correlation_df_stacked.query("Feature_1_1!=Feature_1_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 3051                   Cytoplasm_AreaShapeMaxFeretDiameter
# 4588                     Nuclei_ParentNucleiIncludingEdges
# 5413                        Cells_AreaShapeMinorAxisLength
# 5920                       Cells_AreaShapeMaxFeretDiameter
# 6716                    Cytoplasm_AreaShapeMinorAxisLength
# ...                                                    ...
# 5128061  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...
# 5128126                   Cells_Intensity_MaxIntensity_DNA
# 5128165                   Cells_Intensity_MaxIntensity_DNA
# 5128364                   Cells_Intensity_MaxIntensity_DNA
# 5131635                     Cytoplasm_AreaShapeEulerNumber
#
#                                             feature_name_2  correlation  \
# 3051                        Cells_AreaShapeMajorAxisLength     0.998344
# 4588                         Cytoplasm_NumberObject_Number     0.997139
# 5413                   Cytoplasm_AreaShapeMinFeretDiameter     0.996440
# 5920                    Cytoplasm_AreaShapeMajorAxisLength     0.995947
# 6716                       Cells_AreaShapeMinFeretDiameter     0.995160
# ...                                                    ...          ...
# 5128061                   Cells_Intensity_MaxIntensity_DNA    -0.958140
# 5128126  Nuclei_Texture_InverseDifferenceMoment_DNA_5_0...    -0.958498
# 5128165  Nuclei_Texture_InverseDifferenceMoment_DNA_10_...    -0.958674
# 5128364  Nuclei_Texture_InverseDifferenceMoment_DNA_10_...    -0.959684
# 5131635                        Nuclei_AreaShapeCompactness    -0.974990
#
#         Compartment_1                 Feature_1_1              Feature_2_1  \
# 3051        Cytoplasm   AreaShapeMaxFeretDiameter                     None
# 4588           Nuclei  ParentNucleiIncludingEdges                     None
# 5413            Cells    AreaShapeMinorAxisLength                     None
# 5920            Cells   AreaShapeMaxFeretDiameter                     None
# 6716        Cytoplasm    AreaShapeMinorAxisLength                     None
# ...               ...                         ...                      ...
# 5128061        Nuclei                     Texture  InverseDifferenceMoment
# 5128126         Cells                   Intensity             MaxIntensity
# 5128165         Cells                   Intensity             MaxIntensity
# 5128364         Cells                   Intensity             MaxIntensity
# 5131635     Cytoplasm        AreaShapeEulerNumber                     None
#
#         Feature_3_1 Channel_1  Suffix_1 Compartment_2  \
# 3051           None                             Cells
# 4588           None                         Cytoplasm
# 5413           None                         Cytoplasm
# 5920           None                         Cytoplasm
# 6716           None                             Cells
# ...             ...       ...       ...           ...
# 5128061        None       DNA  5_01_256         Cells
# 5128126        None       DNA                  Nuclei
# 5128165        None       DNA                  Nuclei
# 5128364        None       DNA                  Nuclei
# 5131635        None                            Nuclei
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 3051      AreaShapeMajorAxisLength                     None        None
# 4588                  NumberObject                     None        None
# 5413     AreaShapeMinFeretDiameter                     None        None
# 5920      AreaShapeMajorAxisLength                     None        None
# 6716     AreaShapeMinFeretDiameter                     None        None
# ...                            ...                      ...         ...
# 5128061                  Intensity             MaxIntensity        None
# 5128126                    Texture  InverseDifferenceMoment        None
# 5128165                    Texture  InverseDifferenceMoment        None
# 5128364                    Texture  InverseDifferenceMoment        None
# 5131635       AreaShapeCompactness                     None        None
#
#         Channel_2   Suffix_2
# 3051
# 4588                  Number
# 5413
# 5920
# 6716
# ...           ...        ...
# 5128061       DNA
# 5128126       DNA   5_03_256
# 5128165       DNA  10_02_256
# 5128364       DNA  10_00_256
# 5131635
#
# [1813208 rows x 15 columns]

# %%
# Drop features with the same Channel names

correlation_df_stacked = correlation_df_stacked.query("Channel_1!=Channel_2")

correlation_df_stacked
# Out:
#                                           feature_name_1  \
# 8965                                 Cells_AreaShapeArea
# 12775                     Cells_AreaShapeBoundingBoxArea
# 17623    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA
# 23253                     Cells_AreaShapeBoundingBoxArea
# 25502                           Cells_AreaShapePerimeter
# ...                                                  ...
# 5113772             Cells_Intensity_MinIntensityEdge_DNA
# 5115655                         Nuclei_AreaShapeSolidity
# 5116762                         Nuclei_AreaShapeSolidity
# 5117205                         Nuclei_Granularity_1_RNA
# 5118761       Cells_RadialDistribution_MeanFrac_RNA_3of4
#
#                                           feature_name_2  correlation  \
# 8965         Cytoplasm_Intensity_IntegratedIntensity_DNA     0.992905
# 12775        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.987311
# 17623                           Cells_AreaShapePerimeter     0.978919
# 23253    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA     0.969924
# 25502        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.966940
# ...                                                  ...          ...
# 5113772                         Nuclei_AreaShapeSolidity    -0.888645
# 5115655          Cytoplasm_Intensity_MedianIntensity_DNA    -0.897711
# 5116762   Cytoplasm_Intensity_LowerQuartileIntensity_DNA    -0.903549
# 5117205        Cells_RadialDistribution_MeanFrac_ER_3of4    -0.905960
# 5118761                          Nuclei_Granularity_1_ER    -0.914174
#
#         Compartment_1               Feature_1_1              Feature_2_1  \
# 8965            Cells             AreaShapeArea                     None
# 12775           Cells  AreaShapeBoundingBoxArea                     None
# 17623       Cytoplasm                 Intensity  IntegratedIntensityEdge
# 23253           Cells  AreaShapeBoundingBoxArea                     None
# 25502           Cells        AreaShapePerimeter                     None
# ...               ...                       ...                      ...
# 5113772         Cells                 Intensity         MinIntensityEdge
# 5115655        Nuclei         AreaShapeSolidity                     None
# 5116762        Nuclei         AreaShapeSolidity                     None
# 5117205        Nuclei               Granularity                        1
# 5118761         Cells        RadialDistribution                 MeanFrac
#
#         Feature_3_1 Channel_1 Suffix_1 Compartment_2         Feature_1_2  \
# 8965           None                        Cytoplasm           Intensity
# 12775          None                        Cytoplasm           Intensity
# 17623          None       DNA                  Cells  AreaShapePerimeter
# 23253          None                        Cytoplasm           Intensity
# 25502          None                        Cytoplasm           Intensity
# ...             ...       ...      ...           ...                 ...
# 5113772        None       DNA                 Nuclei   AreaShapeSolidity
# 5115655        None                        Cytoplasm           Intensity
# 5116762        None                        Cytoplasm           Intensity
# 5117205        None       RNA                  Cells  RadialDistribution
# 5118761        None       RNA     3of4        Nuclei         Granularity
#
#                      Feature_2_2 Feature_3_2 Channel_2 Suffix_2
# 8965         IntegratedIntensity        None       DNA
# 12775        IntegratedIntensity        None       DNA
# 17623                       None        None
# 23253    IntegratedIntensityEdge        None       DNA
# 25502        IntegratedIntensity        None       DNA
# ...                          ...         ...       ...      ...
# 5113772                     None        None
# 5115655          MedianIntensity        None       DNA
# 5116762   LowerQuartileIntensity        None       DNA
# 5117205                 MeanFrac        None        ER     3of4
# 5118761                        1        None        ER
#
# [1563400 rows x 15 columns]

# %%
# Compute absolute correlation

correlation_df_stacked = correlation_df_stacked.assign(
    abs_correlation=lambda x: np.abs(x["correlation"])
)

correlation_df_stacked.sort_values(by=["abs_correlation"], ascending=False, inplace=True)

# %%
# Drop Duplicates

correlation_df_stacked = correlation_df_stacked.drop_duplicates(
    subset=["Feature_1_1", "Feature_1_2", "Feature_2_1", "Feature_2_2"], keep="first"
)

correlation_df_stacked
# Out:
#                                           feature_name_1  \
# 8965                                 Cells_AreaShapeArea
# 12775                     Cells_AreaShapeBoundingBoxArea
# 17623    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA
# 23253                     Cells_AreaShapeBoundingBoxArea
# 25502                           Cells_AreaShapePerimeter
# ...                                                  ...
# 3041802                    Cytoplasm_Granularity_10_Mito
# 3041551                      Cytoplasm_Granularity_3_AGP
# 2836030                     Cytoplasm_Granularity_7_Mito
# 3000931                 Cells_Intensity_MaxIntensity_AGP
# 2902192      Nuclei_ObjectSkeletonNumberTrunks_mito_skel
#
#                                           feature_name_2  correlation  \
# 8965         Cytoplasm_Intensity_IntegratedIntensity_DNA     0.992905
# 12775        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.987311
# 17623                           Cells_AreaShapePerimeter     0.978919
# 23253    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA     0.969924
# 25502        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.966940
# ...                                                  ...          ...
# 3041802                      Nuclei_AreaShapeOrientation    -0.010618
# 3041551                      Nuclei_AreaShapeOrientation    -0.010577
# 2836030                      Nuclei_AreaShapeOrientation     0.007672
# 3000931                      Nuclei_AreaShapeOrientation    -0.005264
# 2902192   Cytoplasm_Intensity_LowerQuartileIntensity_AGP     0.002566
#
#         Compartment_1                 Feature_1_1              Feature_2_1  \
# 8965            Cells               AreaShapeArea                     None
# 12775           Cells    AreaShapeBoundingBoxArea                     None
# 17623       Cytoplasm                   Intensity  IntegratedIntensityEdge
# 23253           Cells    AreaShapeBoundingBoxArea                     None
# 25502           Cells          AreaShapePerimeter                     None
# ...               ...                         ...                      ...
# 3041802     Cytoplasm                 Granularity                       10
# 3041551     Cytoplasm                 Granularity                        3
# 2836030     Cytoplasm                 Granularity                        7
# 3000931         Cells                   Intensity             MaxIntensity
# 2902192        Nuclei  ObjectSkeletonNumberTrunks                     None
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2           Feature_1_2  \
# 8965           None                          Cytoplasm             Intensity
# 12775          None                          Cytoplasm             Intensity
# 17623          None       DNA                    Cells    AreaShapePerimeter
# 23253          None                          Cytoplasm             Intensity
# 25502          None                          Cytoplasm             Intensity
# ...             ...       ...        ...           ...                   ...
# 3041802        None      Mito                   Nuclei  AreaShapeOrientation
# 3041551        None       AGP                   Nuclei  AreaShapeOrientation
# 2836030        None      Mito                   Nuclei  AreaShapeOrientation
# 3000931        None       AGP                   Nuclei  AreaShapeOrientation
# 2902192        None            mito_skel     Cytoplasm             Intensity
#
#                      Feature_2_2 Feature_3_2 Channel_2 Suffix_2  \
# 8965         IntegratedIntensity        None       DNA
# 12775        IntegratedIntensity        None       DNA
# 17623                       None        None
# 23253    IntegratedIntensityEdge        None       DNA
# 25502        IntegratedIntensity        None       DNA
# ...                          ...         ...       ...      ...
# 3041802                     None        None
# 3041551                     None        None
# 2836030                     None        None
# 3000931                     None        None
# 2902192   LowerQuartileIntensity        None       AGP
#
#          abs_correlation
# 8965            0.992905
# 12775           0.987311
# 17623           0.978919
# 23253           0.969924
# 25502           0.966940
# ...                  ...
# 3041802         0.010618
# 3041551         0.010577
# 2836030         0.007672
# 3000931         0.005264
# 2902192         0.002566
#
# [4948 rows x 16 columns]

# %%
# Keep only highly correlated features

correlation_df_stacked.sort_values(by=["correlation"], ascending=False, inplace=True)
correlation_df_stacked = correlation_df_stacked.query("correlation>0.8 or correlation<-0.8")

correlation_df_stacked
# Out:
#                                           feature_name_1  \
# 8965                                 Cells_AreaShapeArea
# 12775                     Cells_AreaShapeBoundingBoxArea
# 17623    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA
# 23253                     Cells_AreaShapeBoundingBoxArea
# 25502                           Cells_AreaShapePerimeter
# ...                                                  ...
# 5113772             Cells_Intensity_MinIntensityEdge_DNA
# 5115655                         Nuclei_AreaShapeSolidity
# 5116762                         Nuclei_AreaShapeSolidity
# 5117205                         Nuclei_Granularity_1_RNA
# 5118761       Cells_RadialDistribution_MeanFrac_RNA_3of4
#
#                                           feature_name_2  correlation  \
# 8965         Cytoplasm_Intensity_IntegratedIntensity_DNA     0.992905
# 12775        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.987311
# 17623                           Cells_AreaShapePerimeter     0.978919
# 23253    Cytoplasm_Intensity_IntegratedIntensityEdge_DNA     0.969924
# 25502        Cytoplasm_Intensity_IntegratedIntensity_DNA     0.966940
# ...                                                  ...          ...
# 5113772                         Nuclei_AreaShapeSolidity    -0.888645
# 5115655          Cytoplasm_Intensity_MedianIntensity_DNA    -0.897711
# 5116762   Cytoplasm_Intensity_LowerQuartileIntensity_DNA    -0.903549
# 5117205        Cells_RadialDistribution_MeanFrac_ER_3of4    -0.905960
# 5118761                          Nuclei_Granularity_1_ER    -0.914174
#
#         Compartment_1               Feature_1_1              Feature_2_1  \
# 8965            Cells             AreaShapeArea                     None
# 12775           Cells  AreaShapeBoundingBoxArea                     None
# 17623       Cytoplasm                 Intensity  IntegratedIntensityEdge
# 23253           Cells  AreaShapeBoundingBoxArea                     None
# 25502           Cells        AreaShapePerimeter                     None
# ...               ...                       ...                      ...
# 5113772         Cells                 Intensity         MinIntensityEdge
# 5115655        Nuclei         AreaShapeSolidity                     None
# 5116762        Nuclei         AreaShapeSolidity                     None
# 5117205        Nuclei               Granularity                        1
# 5118761         Cells        RadialDistribution                 MeanFrac
#
#         Feature_3_1 Channel_1 Suffix_1 Compartment_2         Feature_1_2  \
# 8965           None                        Cytoplasm           Intensity
# 12775          None                        Cytoplasm           Intensity
# 17623          None       DNA                  Cells  AreaShapePerimeter
# 23253          None                        Cytoplasm           Intensity
# 25502          None                        Cytoplasm           Intensity
# ...             ...       ...      ...           ...                 ...
# 5113772        None       DNA                 Nuclei   AreaShapeSolidity
# 5115655        None                        Cytoplasm           Intensity
# 5116762        None                        Cytoplasm           Intensity
# 5117205        None       RNA                  Cells  RadialDistribution
# 5118761        None       RNA     3of4        Nuclei         Granularity
#
#                      Feature_2_2 Feature_3_2 Channel_2 Suffix_2  \
# 8965         IntegratedIntensity        None       DNA
# 12775        IntegratedIntensity        None       DNA
# 17623                       None        None
# 23253    IntegratedIntensityEdge        None       DNA
# 25502        IntegratedIntensity        None       DNA
# ...                          ...         ...       ...      ...
# 5113772                     None        None
# 5115655          MedianIntensity        None       DNA
# 5116762   LowerQuartileIntensity        None       DNA
# 5117205                 MeanFrac        None        ER     3of4
# 5118761                        1        None        ER
#
#          abs_correlation
# 8965            0.992905
# 12775           0.987311
# 17623           0.978919
# 23253           0.969924
# 25502           0.966940
# ...                  ...
# 5113772         0.888645
# 5115655         0.897711
# 5116762         0.903549
# 5117205         0.905960
# 5118761         0.914174
#
# [326 rows x 16 columns]

# %%
correlation_df_stacked[["feature_name_1", "feature_name_2", "correlation"]].to_csv('output/crispr_top_correlations.csv', index=False)
