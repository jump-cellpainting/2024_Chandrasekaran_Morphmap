# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %% [markdown]
# Rules
# - Drop Correlation features
# - Drop Object Number features
# - Drop features with X,Y suffix
# - Drop correlations between same compartment features
# - Drop correlations between same Feature categories
# - Keep only one row per feature group
# - Keep only highly correlated/anticorrelated features

# %%
feature_name_cols = ["Compartment", "Feature", "Feature_1", "Feature_2", "Feature_3", "Channel", "Suffix"]

# %%
crispr_feature_df = pd.read_parquet("input/crispr_feature_wide.parquet").rename(
    columns={"Mask": "Compartment"}
)

# Split Feature further
crispr_feature_df[["Feature_1", "Feature_2", "Feature_3"]] = (
    crispr_feature_df.Feature.str.split("_", expand=True)
)

# Remove leading underscore from column values

crispr_feature_df["Suffix"] = crispr_feature_df["Suffix"].apply(lambda x: x.lstrip("_"))

# Create feature name
crispr_feature_df["feature_name"] = crispr_feature_df[feature_name_cols].agg(
    lambda x: "_".join(filter(None, x)), axis=1
)

crispr_feature_df.head()
# Out:
#   Compartment                     Feature Channel     Suffix  column_0  \
# 0       Cells         Texture_Correlation      ER  10_02_256  1.000000
# 1   Cytoplasm    AreaShapeBoundingBoxArea                     0.507748
# 2   Cytoplasm  Intensity_MassDisplacement     RNA             0.606947
# 3   Cytoplasm            Texture_Contrast     DNA  10_02_256  0.002188
# 4   Cytoplasm         Texture_Correlation    Mito  10_01_256  0.486636
#
#    column_1  column_2  column_3  column_4  column_5  ...  column_3645  \
# 0  0.507748  0.606947  0.002188  0.486636  0.603111  ...     0.176715
# 1  1.000000  0.785837 -0.001925  0.575591  0.294705  ...     0.054823
# 2  0.785837  1.000000  0.002393  0.549004  0.280987  ...     0.191329
# 3 -0.001925  0.002393  1.000000 -0.002864 -0.002334  ...     0.005742
# 4  0.575591  0.549004 -0.002864  1.000000  0.478242  ...     0.048198
#
#    column_3646  column_3647  column_3648  column_3649  column_3650  \
# 0     0.463619    -0.301220     0.039268     0.203778     0.043879
# 1    -0.145195    -0.243519    -0.059198     0.125026    -0.160831
# 2    -0.130523    -0.461357     0.196529     0.190383     0.022665
# 3     0.005219    -0.001404     0.008478    -0.000910     0.087698
# 4     0.003907    -0.157372     0.046812     0.083500    -0.040116
#
#                   Feature_1         Feature_2  Feature_3  \
# 0                   Texture       Correlation       None
# 1  AreaShapeBoundingBoxArea              None       None
# 2                 Intensity  MassDisplacement       None
# 3                   Texture          Contrast       None
# 4                   Texture       Correlation       None
#
#                                         feature_name
# 0  Cells_Texture_Correlation_Texture_Correlation_...
# 1  Cytoplasm_AreaShapeBoundingBoxArea_AreaShapeBo...
# 2  Cytoplasm_Intensity_MassDisplacement_Intensity...
# 3  Cytoplasm_Texture_Contrast_Texture_Contrast_DN...
# 4  Cytoplasm_Texture_Correlation_Texture_Correlat...
#
# [5 rows x 3659 columns]

# %%
# Rename column names 

feature_names_df = crispr_feature_df[feature_name_cols + ["feature_name"]].copy()
correlation_df = crispr_feature_df.drop(columns=feature_name_cols).set_index("feature_name")
correlation_df.columns = feature_names_df.feature_name.to_list()

# %%
# Remove Correlation features
feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Correlation")
]

# Remove Object Number features

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("ObjectNumber")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Feature.str.contains("Object_Number")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("X")
]

feature_names_df = feature_names_df[
    ~feature_names_df.Suffix.str.contains("Y")
]


correlation_df = correlation_df.loc[
    feature_names_df.feature_name.to_list(), feature_names_df.feature_name.to_list()
]

# %%
# Stack the dataframe

correlation_df_stacked = (
    correlation_df.mask(np.tril(np.ones(correlation_df.shape)).astype(bool))
    .stack()
    .reset_index()
    .rename(
        columns={
            0: "correlation",
            "feature_name": "feature_name_1",
            "level_1": "feature_name_2",
        }
    )
).sort_values(by=["correlation"], ascending=False)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 1821117  Cells_NeighborsFirstClosestDistance_NeighborsF...
# 4809812  Cells_NeighborsSecondClosestDistance_Neighbors...
# 5055090  Cells_NeighborsAngleBetweenNeighbors_Neighbors...
# 3356164  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 871324   Cytoplasm_RadialDistributionMeanFrac_RadialDis...
# ...                                                    ...
# 2977468  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 820909   Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 3166497  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 2640397  Cytoplasm_RadialDistributionMeanFrac_RadialDis...
# 2977707  Cytoplasm_RadialDistributionFracAtD_RadialDist...
#
#                                             feature_name_2  correlation
# 1821117  Cells_NeighborsFirstClosestDistance_NeighborsF...     1.000000
# 4809812  Cells_NeighborsSecondClosestDistance_Neighbors...     1.000000
# 5055090  Cells_NeighborsAngleBetweenNeighbors_Neighbors...     1.000000
# 3356164  Cytoplasm_RadialDistributionFracAtD_RadialDist...     1.000000
# 871324   Cytoplasm_RadialDistributionMeanFrac_RadialDis...     1.000000
# ...                                                    ...          ...
# 2977468  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997748
# 820909   Cytoplasm_RadialDistributionFracAtD_RadialDist...    -0.997794
# 3166497  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997799
# 2640397  Cytoplasm_RadialDistributionFracAtD_RadialDist...    -0.997951
# 2977707  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997961
#
# [5134410 rows x 3 columns]

# %%
# Add other feature name columns

correlation_df_stacked = (
    correlation_df_stacked.merge(
        feature_names_df, left_on="feature_name_1", right_on="feature_name", how="left"
    )
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_1",
            "Channel": "Channel_1",
            "Suffix": "Suffix_1",
            "Feature_1": "Feature_1_1",
            "Feature_2": "Feature_2_1",
            "Feature_3": "Feature_3_1",
        }
    )
    .merge(feature_names_df, left_on="feature_name_2", right_on="feature_name", how="left")
    .drop(columns=["feature_name", "Feature"])
    .rename(
        columns={
            "Compartment": "Compartment_2",
            "Channel": "Channel_2",
            "Suffix": "Suffix_2",
            "Feature_1": "Feature_1_2",
            "Feature_2": "Feature_2_2",
            "Feature_3": "Feature_3_2",
        }
    )
)
correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 0        Cells_NeighborsFirstClosestDistance_NeighborsF...
# 1        Cells_NeighborsSecondClosestDistance_Neighbors...
# 2        Cells_NeighborsAngleBetweenNeighbors_Neighbors...
# 3        Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 4        Cytoplasm_RadialDistributionMeanFrac_RadialDis...
# ...                                                    ...
# 5134405  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 5134406  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 5134407  Cytoplasm_RadialDistributionFracAtD_RadialDist...
# 5134408  Cytoplasm_RadialDistributionMeanFrac_RadialDis...
# 5134409  Cytoplasm_RadialDistributionFracAtD_RadialDist...
#
#                                             feature_name_2  correlation  \
# 0        Cells_NeighborsFirstClosestDistance_NeighborsF...     1.000000
# 1        Cells_NeighborsSecondClosestDistance_Neighbors...     1.000000
# 2        Cells_NeighborsAngleBetweenNeighbors_Neighbors...     1.000000
# 3        Cytoplasm_RadialDistributionFracAtD_RadialDist...     1.000000
# 4        Cytoplasm_RadialDistributionMeanFrac_RadialDis...     1.000000
# ...                                                    ...          ...
# 5134405  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997748
# 5134406  Cytoplasm_RadialDistributionFracAtD_RadialDist...    -0.997794
# 5134407  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997799
# 5134408  Cytoplasm_RadialDistributionFracAtD_RadialDist...    -0.997951
# 5134409  Cytoplasm_RadialDistributionMeanFrac_RadialDis...    -0.997961
#
#         Compartment_1                     Feature_1_1 Feature_2_1 Feature_3_1  \
# 0               Cells   NeighborsFirstClosestDistance        None        None
# 1               Cells  NeighborsSecondClosestDistance        None        None
# 2               Cells  NeighborsAngleBetweenNeighbors        None        None
# 3           Cytoplasm       RadialDistributionFracAtD        None        None
# 4           Cytoplasm      RadialDistributionMeanFrac        None        None
# ...               ...                             ...         ...         ...
# 5134405     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134406     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134407     Cytoplasm       RadialDistributionFracAtD        None        None
# 5134408     Cytoplasm      RadialDistributionMeanFrac        None        None
# 5134409     Cytoplasm       RadialDistributionFracAtD        None        None
#
#         Channel_1              Suffix_1 Compartment_2  \
# 0                              Adjacent         Cells
# 1                              Adjacent         Cells
# 2                                     5         Cells
# 3                   mito_tubeness_1of20     Cytoplasm
# 4                   mito_tubeness_1of20     Cytoplasm
# ...           ...                   ...           ...
# 5134405            mito_tubeness_20of20     Cytoplasm
# 5134406            mito_tubeness_18of20     Cytoplasm
# 5134407            mito_tubeness_16of16     Cytoplasm
# 5134408            mito_tubeness_17of20     Cytoplasm
# 5134409            mito_tubeness_20of20     Cytoplasm
#
#                             Feature_1_2 Feature_2_2 Feature_3_2 Channel_2  \
# 0         NeighborsFirstClosestDistance        None        None
# 1        NeighborsSecondClosestDistance        None        None
# 2        NeighborsAngleBetweenNeighbors        None        None
# 3             RadialDistributionFracAtD        None        None
# 4            RadialDistributionMeanFrac        None        None
# ...                                 ...         ...         ...       ...
# 5134405      RadialDistributionMeanFrac        None        None
# 5134406       RadialDistributionFracAtD        None        None
# 5134407      RadialDistributionMeanFrac        None        None
# 5134408       RadialDistributionFracAtD        None        None
# 5134409      RadialDistributionMeanFrac        None        None
#
#                      Suffix_2
# 0                           5
# 1                           5
# 2                    Adjacent
# 3         mito_tubeness_1of16
# 4         mito_tubeness_1of16
# ...                       ...
# 5134405  mito_tubeness_18of20
# 5134406  mito_tubeness_16of16
# 5134407  mito_tubeness_14of16
# 5134408  mito_tubeness_16of16
# 5134409  mito_tubeness_14of16
#
# [5134410 rows x 15 columns]

# %%
# Drop correlations between same compartment features

correlation_df_stacked = correlation_df_stacked.query("Compartment_1!=Compartment_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 5                  Nuclei_NumberObject_NumberObject_Number
# 27       Cells_AreaShapeMinFeretDiameter_AreaShapeMinFe...
# 44       Cells_AreaShapeMaxFeretDiameter_AreaShapeMaxFe...
# 140      Cytoplasm_AreaShapeBoundingBoxArea_AreaShapeBo...
# 735      Cytoplasm_Intensity_MinIntensityEdge_Intensity...
# ...                                                    ...
# 5132443  Cells_Texture_DifferenceEntropy_Texture_Differ...
# 5132455  Cells_Texture_DifferenceEntropy_Texture_Differ...
# 5132462  Cells_Texture_DifferenceEntropy_Texture_Differ...
# 5132598  Cells_Texture_DifferenceEntropy_Texture_Differ...
# 5132607  Nuclei_Texture_InverseDifferenceMoment_Texture...
#
#                                             feature_name_2  correlation  \
# 5               Cytoplasm_NumberObject_NumberObject_Number     0.999999
# 27       Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.999984
# 44       Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...     0.999966
# 140      Cells_AreaShapeBoundingBoxArea_AreaShapeBoundi...     0.999931
# 735      Cells_Intensity_MinIntensityEdge_Intensity_Min...     0.999735
# ...                                                    ...          ...
# 5132443  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.979870
# 5132455  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.979962
# 5132462  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.980010
# 5132598  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.980713
# 5132607  Cells_Texture_DifferenceEntropy_Texture_Differ...    -0.980751
#
#         Compartment_1                Feature_1_1              Feature_2_1  \
# 5              Nuclei               NumberObject                     None
# 27              Cells  AreaShapeMinFeretDiameter                     None
# 44              Cells  AreaShapeMaxFeretDiameter                     None
# 140         Cytoplasm   AreaShapeBoundingBoxArea                     None
# 735         Cytoplasm                  Intensity         MinIntensityEdge
# ...               ...                        ...                      ...
# 5132443         Cells                    Texture        DifferenceEntropy
# 5132455         Cells                    Texture        DifferenceEntropy
# 5132462         Cells                    Texture        DifferenceEntropy
# 5132598         Cells                    Texture        DifferenceEntropy
# 5132607        Nuclei                    Texture  InverseDifferenceMoment
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 5              None               Number     Cytoplasm
# 27             None                          Cytoplasm
# 44             None                          Cytoplasm
# 140            None                              Cells
# 735            None        ER                    Cells
# ...             ...       ...        ...           ...
# 5132443        None       DNA  10_03_256        Nuclei
# 5132455        None       DNA  10_03_256        Nuclei
# 5132462        None       DNA  10_01_256        Nuclei
# 5132598        None       DNA  10_03_256        Nuclei
# 5132607        None       DNA   5_01_256         Cells
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 5                     NumberObject                     None        None
# 27       AreaShapeMinFeretDiameter                     None        None
# 44       AreaShapeMaxFeretDiameter                     None        None
# 140       AreaShapeBoundingBoxArea                     None        None
# 735                      Intensity         MinIntensityEdge        None
# ...                            ...                      ...         ...
# 5132443                    Texture  InverseDifferenceMoment        None
# 5132455                    Texture  InverseDifferenceMoment        None
# 5132462                    Texture  InverseDifferenceMoment        None
# 5132598                    Texture  InverseDifferenceMoment        None
# 5132607                    Texture        DifferenceEntropy        None
#
#         Channel_2   Suffix_2
# 5                     Number
# 27
# 44
# 140
# 735            ER
# ...           ...        ...
# 5132443       DNA   3_03_256
# 5132455       DNA   5_01_256
# 5132462       DNA   5_03_256
# 5132598       DNA   5_03_256
# 5132607       DNA  10_01_256
#
# [3421826 rows x 15 columns]

# %%
# Drop correlations between same Feature_1 features

correlation_df_stacked = correlation_df_stacked.query("Feature_1_1!=Feature_1_2")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 3051     Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...
# 4588     Nuclei_ParentNucleiIncludingEdges_ParentNuclei...
# 5413     Cells_AreaShapeMinorAxisLength_AreaShapeMinorA...
# 5920     Cells_AreaShapeMaxFeretDiameter_AreaShapeMaxFe...
# 6716     Cytoplasm_AreaShapeMinorAxisLength_AreaShapeMi...
# ...                                                    ...
# 5128061  Nuclei_Texture_InverseDifferenceMoment_Texture...
# 5128126  Cells_Intensity_MaxIntensity_Intensity_MaxInte...
# 5128165  Cells_Intensity_MaxIntensity_Intensity_MaxInte...
# 5128364  Cells_Intensity_MaxIntensity_Intensity_MaxInte...
# 5131635  Cytoplasm_AreaShapeEulerNumber_AreaShapeEulerN...
#
#                                             feature_name_2  correlation  \
# 3051     Cells_AreaShapeMajorAxisLength_AreaShapeMajorA...     0.998344
# 4588            Cytoplasm_NumberObject_NumberObject_Number     0.997139
# 5413     Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.996440
# 5920     Cytoplasm_AreaShapeMajorAxisLength_AreaShapeMa...     0.995947
# 6716     Cells_AreaShapeMinFeretDiameter_AreaShapeMinFe...     0.995160
# ...                                                    ...          ...
# 5128061  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.958140
# 5128126  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.958498
# 5128165  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.958674
# 5128364  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.959684
# 5131635   Nuclei_AreaShapeCompactness_AreaShapeCompactness    -0.974990
#
#         Compartment_1                 Feature_1_1              Feature_2_1  \
# 3051        Cytoplasm   AreaShapeMaxFeretDiameter                     None
# 4588           Nuclei  ParentNucleiIncludingEdges                     None
# 5413            Cells    AreaShapeMinorAxisLength                     None
# 5920            Cells   AreaShapeMaxFeretDiameter                     None
# 6716        Cytoplasm    AreaShapeMinorAxisLength                     None
# ...               ...                         ...                      ...
# 5128061        Nuclei                     Texture  InverseDifferenceMoment
# 5128126         Cells                   Intensity             MaxIntensity
# 5128165         Cells                   Intensity             MaxIntensity
# 5128364         Cells                   Intensity             MaxIntensity
# 5131635     Cytoplasm        AreaShapeEulerNumber                     None
#
#         Feature_3_1 Channel_1  Suffix_1 Compartment_2  \
# 3051           None                             Cells
# 4588           None                         Cytoplasm
# 5413           None                         Cytoplasm
# 5920           None                         Cytoplasm
# 6716           None                             Cells
# ...             ...       ...       ...           ...
# 5128061        None       DNA  5_01_256         Cells
# 5128126        None       DNA                  Nuclei
# 5128165        None       DNA                  Nuclei
# 5128364        None       DNA                  Nuclei
# 5131635        None                            Nuclei
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 3051      AreaShapeMajorAxisLength                     None        None
# 4588                  NumberObject                     None        None
# 5413     AreaShapeMinFeretDiameter                     None        None
# 5920      AreaShapeMajorAxisLength                     None        None
# 6716     AreaShapeMinFeretDiameter                     None        None
# ...                            ...                      ...         ...
# 5128061                  Intensity             MaxIntensity        None
# 5128126                    Texture  InverseDifferenceMoment        None
# 5128165                    Texture  InverseDifferenceMoment        None
# 5128364                    Texture  InverseDifferenceMoment        None
# 5131635       AreaShapeCompactness                     None        None
#
#         Channel_2   Suffix_2
# 3051
# 4588                  Number
# 5413
# 5920
# 6716
# ...           ...        ...
# 5128061       DNA
# 5128126       DNA   5_03_256
# 5128165       DNA  10_02_256
# 5128364       DNA  10_00_256
# 5131635
#
# [1813208 rows x 15 columns]

# %%
# Compute absolute correlation

correlation_df_stacked = correlation_df_stacked.assign(
    abs_correlation=lambda x: np.abs(x["correlation"])
)

correlation_df_stacked.sort_values(by=["abs_correlation"], ascending=False, inplace=True)

# %%
# Drop Duplicates

correlation_df_stacked = correlation_df_stacked.drop_duplicates(
    subset=["Feature_1_1", "Feature_1_2", "Feature_2_1", "Feature_2_2"], keep="first"
)

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 3051     Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...
# 4588     Nuclei_ParentNucleiIncludingEdges_ParentNuclei...
# 5413     Cells_AreaShapeMinorAxisLength_AreaShapeMinorA...
# 8965                     Cells_AreaShapeArea_AreaShapeArea
# 10014    Cells_AreaShapeEquivalentDiameter_AreaShapeEqu...
# ...                                                    ...
# 2921217  Nuclei_ObjectSkeletonNumberNonTrunkBranches_Ob...
# 2961130  Cells_NeighborsFirstClosestDistance_NeighborsF...
# 2960348  Nuclei_ObjectSkeletonNumberBranchEnds_ObjectSk...
# 2957310  Nuclei_ObjectSkeletonTotalObjectSkeletonLength...
# 2934568    Cytoplasm_AreaShapePerimeter_AreaShapePerimeter
#
#                                             feature_name_2  correlation  \
# 3051     Cells_AreaShapeMajorAxisLength_AreaShapeMajorA...     0.998344
# 4588            Cytoplasm_NumberObject_NumberObject_Number     0.997139
# 5413     Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.996440
# 8965     Cytoplasm_Intensity_IntegratedIntensity_Intens...     0.992905
# 10014    Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.991642
# ...                                                    ...          ...
# 2921217    Cells_ChildrenCytoplasm_ChildrenCytoplasm_Count     0.001466
# 2961130   Nuclei_AreaShapeOrientation_AreaShapeOrientation    -0.001345
# 2960348  Cells_NeighborsAngleBetweenNeighbors_Neighbors...    -0.001279
# 2957310  Cells_AreaShapeEquivalentDiameter_AreaShapeEqu...    -0.001022
# 2934568   Nuclei_AreaShapeOrientation_AreaShapeOrientation     0.000655
#
#         Compartment_1                              Feature_1_1 Feature_2_1  \
# 3051        Cytoplasm                AreaShapeMaxFeretDiameter        None
# 4588           Nuclei               ParentNucleiIncludingEdges        None
# 5413            Cells                 AreaShapeMinorAxisLength        None
# 8965            Cells                            AreaShapeArea        None
# 10014           Cells              AreaShapeEquivalentDiameter        None
# ...               ...                                      ...         ...
# 2921217        Nuclei     ObjectSkeletonNumberNonTrunkBranches        None
# 2961130         Cells            NeighborsFirstClosestDistance        None
# 2960348        Nuclei           ObjectSkeletonNumberBranchEnds        None
# 2957310        Nuclei  ObjectSkeletonTotalObjectSkeletonLength        None
# 2934568     Cytoplasm                       AreaShapePerimeter        None
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 3051           None                              Cells
# 4588           None                          Cytoplasm
# 5413           None                          Cytoplasm
# 8965           None                          Cytoplasm
# 10014          None                          Cytoplasm
# ...             ...       ...        ...           ...
# 2921217        None            mito_skel         Cells
# 2961130        None             Adjacent        Nuclei
# 2960348        None            mito_skel         Cells
# 2957310        None            mito_skel         Cells
# 2934568        None                             Nuclei
#
#                             Feature_1_2          Feature_2_2 Feature_3_2  \
# 3051           AreaShapeMajorAxisLength                 None        None
# 4588                       NumberObject                 None        None
# 5413          AreaShapeMinFeretDiameter                 None        None
# 8965                          Intensity  IntegratedIntensity        None
# 10014         AreaShapeMinFeretDiameter                 None        None
# ...                                 ...                  ...         ...
# 2921217               ChildrenCytoplasm                 None        None
# 2961130            AreaShapeOrientation                 None        None
# 2960348  NeighborsAngleBetweenNeighbors                 None        None
# 2957310     AreaShapeEquivalentDiameter                 None        None
# 2934568            AreaShapeOrientation                 None        None
#
#         Channel_2 Suffix_2  abs_correlation
# 3051                               0.998344
# 4588                Number         0.997139
# 5413                               0.996440
# 8965          DNA                  0.992905
# 10014                              0.991642
# ...           ...      ...              ...
# 2921217              Count         0.001466
# 2961130                            0.001345
# 2960348                  5         0.001279
# 2957310                            0.001022
# 2934568                            0.000655
#
# [5887 rows x 16 columns]

# %%
# Keep only highly correlated features

correlation_df_stacked.sort_values(by=["correlation"], ascending=False, inplace=True)
correlation_df_stacked = correlation_df_stacked.query("correlation>0.75 or correlation<-0.75")

correlation_df_stacked
# Out:
#                                             feature_name_1  \
# 3051     Cytoplasm_AreaShapeMaxFeretDiameter_AreaShapeM...
# 4588     Nuclei_ParentNucleiIncludingEdges_ParentNuclei...
# 5413     Cells_AreaShapeMinorAxisLength_AreaShapeMinorA...
# 8965                     Cells_AreaShapeArea_AreaShapeArea
# 10014    Cells_AreaShapeEquivalentDiameter_AreaShapeEqu...
# ...                                                    ...
# 5125701  Cells_Texture_InverseDifferenceMoment_Texture_...
# 5126804  Cells_Texture_InverseDifferenceMoment_Texture_...
# 5128061  Nuclei_Texture_InverseDifferenceMoment_Texture...
# 5128364  Cells_Intensity_MaxIntensity_Intensity_MaxInte...
# 5131635  Cytoplasm_AreaShapeEulerNumber_AreaShapeEulerN...
#
#                                             feature_name_2  correlation  \
# 3051     Cells_AreaShapeMajorAxisLength_AreaShapeMajorA...     0.998344
# 4588            Cytoplasm_NumberObject_NumberObject_Number     0.997139
# 5413     Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.996440
# 8965     Cytoplasm_Intensity_IntegratedIntensity_Intens...     0.992905
# 10014    Cytoplasm_AreaShapeMinFeretDiameter_AreaShapeM...     0.991642
# ...                                                    ...          ...
# 5125701  Nuclei_Intensity_UpperQuartileIntensity_Intens...    -0.948061
# 5126804  Nuclei_Intensity_MeanIntensity_Intensity_MeanI...    -0.952922
# 5128061  Cells_Intensity_MaxIntensity_Intensity_MaxInte...    -0.958140
# 5128364  Nuclei_Texture_InverseDifferenceMoment_Texture...    -0.959684
# 5131635   Nuclei_AreaShapeCompactness_AreaShapeCompactness    -0.974990
#
#         Compartment_1                  Feature_1_1              Feature_2_1  \
# 3051        Cytoplasm    AreaShapeMaxFeretDiameter                     None
# 4588           Nuclei   ParentNucleiIncludingEdges                     None
# 5413            Cells     AreaShapeMinorAxisLength                     None
# 8965            Cells                AreaShapeArea                     None
# 10014           Cells  AreaShapeEquivalentDiameter                     None
# ...               ...                          ...                      ...
# 5125701         Cells                      Texture  InverseDifferenceMoment
# 5126804         Cells                      Texture  InverseDifferenceMoment
# 5128061        Nuclei                      Texture  InverseDifferenceMoment
# 5128364         Cells                    Intensity             MaxIntensity
# 5131635     Cytoplasm         AreaShapeEulerNumber                     None
#
#         Feature_3_1 Channel_1   Suffix_1 Compartment_2  \
# 3051           None                              Cells
# 4588           None                          Cytoplasm
# 5413           None                          Cytoplasm
# 8965           None                          Cytoplasm
# 10014          None                          Cytoplasm
# ...             ...       ...        ...           ...
# 5125701        None       DNA  10_01_256        Nuclei
# 5126804        None       DNA  10_01_256        Nuclei
# 5128061        None       DNA   5_01_256         Cells
# 5128364        None       DNA                   Nuclei
# 5131635        None                             Nuclei
#
#                        Feature_1_2              Feature_2_2 Feature_3_2  \
# 3051      AreaShapeMajorAxisLength                     None        None
# 4588                  NumberObject                     None        None
# 5413     AreaShapeMinFeretDiameter                     None        None
# 8965                     Intensity      IntegratedIntensity        None
# 10014    AreaShapeMinFeretDiameter                     None        None
# ...                            ...                      ...         ...
# 5125701                  Intensity   UpperQuartileIntensity        None
# 5126804                  Intensity            MeanIntensity        None
# 5128061                  Intensity             MaxIntensity        None
# 5128364                    Texture  InverseDifferenceMoment        None
# 5131635       AreaShapeCompactness                     None        None
#
#         Channel_2   Suffix_2  abs_correlation
# 3051                                 0.998344
# 4588                  Number         0.997139
# 5413                                 0.996440
# 8965          DNA                    0.992905
# 10014                                0.991642
# ...           ...        ...              ...
# 5125701       DNA                    0.948061
# 5126804       DNA                    0.952922
# 5128061       DNA                    0.958140
# 5128364       DNA  10_00_256         0.959684
# 5131635                              0.974990
#
# [1079 rows x 16 columns]

# %%
correlation_df_stacked[["feature_name_1", "feature_name_2", "correlation"]].to_csv('output/crispr_top_correlations.csv', index=False)
