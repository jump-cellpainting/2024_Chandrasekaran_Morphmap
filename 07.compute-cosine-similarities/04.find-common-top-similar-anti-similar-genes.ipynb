# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n_connections = {
    "orf": {
        "similar": 100,
        "anti_similar": 100,
        },
    "crispr": {
        "similar": 100,
        "anti_similar": 100,
    }
}

similar_threshold = 0.6
anti_similar_threshold = -0.6

# %% [markdown]
# How many gene pairs are common between the top similar and anti-similar ORF and CRISPR genes?

# %%
gene_similarity_df_stacked = pd.DataFrame()

for modality, value in n_connections.items():
    for direction, n in value.items():
        df = pd.read_csv(f"output/{modality}_top_{direction}_genes.csv", index_col=0)
        df_stacked = (
            df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
            .stack()
            .reset_index()
            .rename(columns={0: "cos_sim", "level_0": "gene_1", "level_1": "gene_2"})
        )
        df_stacked = df_stacked.query("gene_1 != gene_2")
        if direction == "similar":
            top_genes_stacked = df_stacked.nlargest(n, "cos_sim")
        elif direction == "anti_similar":
            top_genes_stacked = df_stacked.nsmallest(n, "cos_sim")
        top_genes_stacked["modality"] = modality
        top_genes_stacked["direction"] = direction

        gene_similarity_df_stacked = pd.concat(
            [gene_similarity_df_stacked, top_genes_stacked], axis=0, ignore_index=True
        )

# %%
orf_df = (
    gene_similarity_df_stacked.query("modality == 'orf'")
    .reset_index(drop=True)
    .rename(columns={"gene_1": "gene_1_orf", "gene_2": "gene_2_orf"})
).drop(columns=["modality"])
crispr_df = (
    gene_similarity_df_stacked.query("modality == 'crispr'")
    .reset_index(drop=True)
    .rename(columns={"gene_1": "gene_1_crispr", "gene_2": "gene_2_crispr"})
).drop(columns=["modality"])

# %%
orf_crispr_similarity_df = pd.concat(
    [
        orf_df.merge(
            crispr_df,
            left_on=["gene_1_orf", "gene_2_orf"],
            right_on=["gene_1_crispr", "gene_2_crispr"],
            suffixes=("_orf", "_crispr"),
            how="inner",
        ),
        orf_df.merge(
            crispr_df,
            left_on=["gene_1_orf", "gene_2_orf"],
            right_on=["gene_2_crispr", "gene_1_crispr"],
            suffixes=("_orf", "_crispr"),
            how="inner",
        ),
    ],
    ignore_index=True,
)

orf_crispr_similarity_df.head()
# Out:
# Empty DataFrame
# Columns: [gene_1_orf, gene_2_orf, cos_sim_orf, direction_orf, gene_1_crispr, gene_2_crispr, cos_sim_crispr, direction_crispr]
# Index: []

# %% [markdown]
# There aren't any gene pairs that are present in both the ORF and CRISPR dataframes. Below I look for such pairs by defining top similar and anti-similar gene pairs as those with a cosine similarity greater than 0.5 or less than -0.5, respectively.

# %%
orf_df_all = pd.read_parquet("cos_sim/cosine_similarities_genes_orf.parquet")
orf_df = (
    orf_df_all.where(np.triu(np.ones(orf_df_all.shape), k=1).astype(bool))
    .stack()
    .reset_index()
    .rename(columns={0: "cos_sim", "level_0": "gene_1_orf", "level_1": "gene_2_orf"})
    .query("gene_1_orf != gene_2_orf")
    .query("cos_sim > @similar_threshold or cos_sim < @anti_similar_threshold")
    .reset_index(drop=True)
    .assign(
        direction=lambda x: np.where(
            x["cos_sim"] > similar_threshold, "similar", "anti_similar"
        )
    )
)

orf_df.head()
# Out:
#   gene_1_orf gene_2_orf   cos_sim direction
# 0      GMEB1     ZBTB14  0.608572   similar
# 1      GMEB1       ZIC1  0.748864   similar
# 2       EBF1       EBF3  0.614303   similar
# 3      ASCL4      ASCL2  0.688542   similar
# 4       FLI1        ERG  0.616079   similar

# %%
crispr_df_all = pd.read_parquet("cos_sim/cosine_similarities_genes_crispr.parquet")
crispr_df = (
    crispr_df_all.where(np.triu(np.ones(crispr_df_all.shape), k=1).astype(bool))
    .stack()
    .reset_index()
    .rename(columns={0: "cos_sim", "level_0": "gene_1_crispr", "level_1": "gene_2_crispr"})
    .query("gene_1_crispr != gene_2_crispr")
    .query("cos_sim > @similar_threshold or cos_sim < @anti_similar_threshold")
    .reset_index(drop=True)
    .assign(
        direction=lambda x: np.where(
            x["cos_sim"] > similar_threshold, "similar", "anti_similar"
        )
    )
)

crispr_df.head()
# Out:
#   gene_1_crispr gene_2_crispr   cos_sim     direction
# 0         PALS2        MRPL58 -0.643831  anti_similar
# 1         PALS2       GUCY1B1  0.720265       similar
# 2         PALS2        ATP5PO  0.735649       similar
# 3         PALS2         TMT1B -0.740775  anti_similar
# 4         PALS2          MMUT -0.778022  anti_similar

# %%
# Combine ORF and CRISPR

orf_crispr_similarity_df = pd.concat(
    [
        orf_df.merge(
            crispr_df,
            left_on=["gene_1_orf", "gene_2_orf"],
            right_on=["gene_1_crispr", "gene_2_crispr"],
            suffixes=("_orf", "_crispr"),
            how="inner",
        ),
        orf_df.merge(
            crispr_df,
            left_on=["gene_1_orf", "gene_2_orf"],
            right_on=["gene_2_crispr", "gene_1_crispr"],
            suffixes=("_orf", "_crispr"),
            how="inner",
        ),
    ],
    ignore_index=True,
)

# %% [markdown]
# Gene pairs where the ORF and CRISPR direction are the same

# %%
same_direction_df = orf_crispr_similarity_df.query("direction_orf == direction_crispr").reset_index(drop=True)
same_direction_df
# Out:
#    gene_1_orf gene_2_orf  cos_sim_orf direction_orf gene_1_crispr  \
# 0      NDUFB5      LACTB     0.600244       similar        NDUFB5
# 1        MRM3       GATM     0.613543       similar          MRM3
# 2        MRM3       PDK2     0.605726       similar          MRM3
# 3        MRM3     GLYCTK     0.641531       similar          MRM3
# 4        RSKR      COX11     0.724281       similar          RSKR
# 5        RSKR      LACTB     0.707552       similar          RSKR
# 6       PTGR3      SIRT3     0.601939       similar         PTGR3
# 7       PTGR3     BCKDHA     0.757269       similar         PTGR3
# 8       PTGR3     ECHDC3     0.727363       similar         PTGR3
# 9       PTGR3      GLUD1     0.692587       similar         PTGR3
# 10   CHRFAM7A     KCNK16     0.740435       similar      CHRFAM7A
# 11      OXER1     GPR176     0.731979       similar         OXER1
# 12        ERG       ZIC1     0.629029       similar          ZIC1
# 13     RHBDL1     GABRA6     0.608581       similar        GABRA6
# 14     CKMT1A      BNIP3     0.684870       similar         BNIP3
# 15       PDK3    CYP11B1     0.662968       similar       CYP11B1
# 16      CHRM1       XCR1     0.613183       similar          XCR1
# 17      STK38     STK38L     0.722713       similar        STK38L
# 18      BCKDK     GLYCTK     0.701795       similar        GLYCTK
# 19       MRM3      PTGR3     0.769992       similar         PTGR3
# 20     CSNK1D     CSNK1E     0.820841       similar        CSNK1E
# 21       GATM      PTGR3     0.672370       similar         PTGR3
# 22    CYP11B1    GLYATL1     0.740238       similar       GLYATL1
# 23       OPN5     ADORA1     0.619580       similar        ADORA1
# 24      GNRHR   CHRFAM7A     0.701581       similar      CHRFAM7A
# 25      GNRHR     KCNK16     0.774030       similar        KCNK16
# 26      GNRHR      OXER1     0.697032       similar         OXER1
# 27      GNRHR     GPR176     0.861991       similar        GPR176
# 28   CHRFAM7A      OXER1     0.746905       similar         OXER1
# 29   CHRFAM7A     GPR176     0.760850       similar        GPR176
# 30     KCNK16      OXER1     0.644085       similar         OXER1
#
#    gene_2_crispr  cos_sim_crispr direction_crispr
# 0          LACTB        0.655382          similar
# 1           GATM        0.755840          similar
# 2           PDK2        0.687652          similar
# 3         GLYCTK        0.614883          similar
# 4          COX11        0.606967          similar
# 5          LACTB        0.607242          similar
# 6          SIRT3        0.781995          similar
# 7         BCKDHA        0.734925          similar
# 8         ECHDC3        0.637581          similar
# 9          GLUD1        0.736492          similar
# 10        KCNK16        0.601201          similar
# 11        GPR176        0.607809          similar
# 12           ERG        0.660054          similar
# 13        RHBDL1        0.737576          similar
# 14        CKMT1A        0.633991          similar
# 15          PDK3        0.697956          similar
# 16         CHRM1        0.647484          similar
# 17         STK38        0.622633          similar
# 18         BCKDK        0.630277          similar
# 19          MRM3        0.739494          similar
# 20        CSNK1D        0.809855          similar
# 21          GATM        0.660831          similar
# 22       CYP11B1        0.617607          similar
# 23          OPN5        0.746113          similar
# 24         GNRHR        0.685079          similar
# 25         GNRHR        0.651814          similar
# 26         GNRHR        0.645012          similar
# 27         GNRHR        0.644439          similar
# 28      CHRFAM7A        0.791201          similar
# 29      CHRFAM7A        0.756003          similar
# 30        KCNK16        0.683122          similar

# %%
diff_direction_df = orf_crispr_similarity_df.query("direction_orf != direction_crispr").reset_index(drop=True)
diff_direction_df
# Out:
#    gene_1_orf gene_2_orf  cos_sim_orf direction_orf gene_1_crispr  \
# 0        GJC1   CHRFAM7A     0.627483       similar          GJC1
# 1        GJC1     KCNK16     0.604098       similar          GJC1
# 2        GJC1      OXER1     0.607918       similar          GJC1
# 3       STT3A   CHRFAM7A     0.601129       similar         STT3A
# 4      RHBDL1      GNRHR     0.601994       similar        RHBDL1
# 5      CKMT1A      LACTB     0.675819       similar        CKMT1A
# 6       CHRM1      GNRHR     0.739185       similar         CHRM1
# 7       CHRM1     GPR176     0.716921       similar         CHRM1
# 8        MRM3    CYP11B1     0.733800       similar          MRM3
# 9       PTGR3    CYP11B1     0.785363       similar         PTGR3
# 10      PTGR3     ACADVL     0.639725       similar         PTGR3
# 11       DRD2     GPR176     0.611000       similar          DRD2
# 12   SLC25A25      LACTB     0.746425       similar      SLC25A25
# 13    TSC22D1     BDKRB1     0.642253       similar        BDKRB1
# 14     KCNJ11       OPN5     0.628914       similar          OPN5
# 15     KCNJ11     ADORA1     0.701158       similar        ADORA1
# 16     RHBDL1   CHRFAM7A     0.727178       similar      CHRFAM7A
# 17     RHBDL1     KCNK16     0.625806       similar        KCNK16
# 18     RHBDL1      OXER1     0.748669       similar         OXER1
# 19     CKMT1A      COX11     0.639816       similar         COX11
# 20       PDK3      PTGR3     0.665916       similar         PTGR3
# 21      TSSK4   SLC25A25     0.602412       similar      SLC25A25
# 22     MAP3K8     MAP3K2     0.691149       similar        MAP3K2
# 23       PDK2    CYP11B1     0.610081       similar       CYP11B1
# 24     CTDSP2       CD40     0.604150       similar          CD40
# 25    CYP11B1     BCKDHA     0.686565       similar        BCKDHA
# 26    CYP11B1      GLUD1     0.648282       similar         GLUD1
# 27     GABRA6   CHRFAM7A     0.702031       similar      CHRFAM7A
# 28     GABRA6     GPR176     0.607494       similar        GPR176
# 29     MAP2K6    GADD45G     0.779971       similar       GADD45G
#
#    gene_2_crispr  cos_sim_crispr direction_crispr
# 0       CHRFAM7A       -0.747611     anti_similar
# 1         KCNK16       -0.613806     anti_similar
# 2          OXER1       -0.704054     anti_similar
# 3       CHRFAM7A       -0.624841     anti_similar
# 4          GNRHR       -0.675877     anti_similar
# 5          LACTB       -0.609599     anti_similar
# 6          GNRHR       -0.652403     anti_similar
# 7         GPR176       -0.727864     anti_similar
# 8        CYP11B1       -0.701983     anti_similar
# 9        CYP11B1       -0.765547     anti_similar
# 10        ACADVL       -0.697121     anti_similar
# 11        GPR176       -0.650968     anti_similar
# 12         LACTB       -0.669568     anti_similar
# 13       TSC22D1       -0.688573     anti_similar
# 14        KCNJ11       -0.683013     anti_similar
# 15        KCNJ11       -0.647853     anti_similar
# 16        RHBDL1       -0.647262     anti_similar
# 17        RHBDL1       -0.620705     anti_similar
# 18        RHBDL1       -0.667978     anti_similar
# 19        CKMT1A       -0.723202     anti_similar
# 20          PDK3       -0.820991     anti_similar
# 21         TSSK4       -0.615375     anti_similar
# 22        MAP3K8       -0.617858     anti_similar
# 23          PDK2       -0.636268     anti_similar
# 24        CTDSP2       -0.683967     anti_similar
# 25       CYP11B1       -0.764802     anti_similar
# 26       CYP11B1       -0.657922     anti_similar
# 27        GABRA6       -0.682153     anti_similar
# 28        GABRA6       -0.680657     anti_similar
# 29        MAP2K6       -0.635430     anti_similar

# %%
same_direction_genes = list(
    np.unique([same_direction_df.gene_1_orf, same_direction_df.gene_2_orf])
)

diff_direction_genes = list(
    np.unique([diff_direction_df.gene_1_orf, diff_direction_df.gene_2_orf])
)

orf_same_direction_df = orf_df_all.loc[same_direction_genes, same_direction_genes]
crispr_same_direction_df = crispr_df_all.loc[same_direction_genes, same_direction_genes]
orf_diff_direction_df = orf_df_all.loc[diff_direction_genes, diff_direction_genes]
crispr_diff_direction_df = crispr_df_all.loc[diff_direction_genes, diff_direction_genes]

# %%
same_direction_matrix = np.triu(orf_same_direction_df)
same_direction_matrix += np.tril(crispr_same_direction_df)
np.fill_diagonal(same_direction_matrix, 0)

same_direction_matrix_df = pd.DataFrame(
    same_direction_matrix, index=same_direction_genes, columns=same_direction_genes
)

different_direction_matrix = np.triu(orf_diff_direction_df)
different_direction_matrix += np.tril(crispr_diff_direction_df)
np.fill_diagonal(different_direction_matrix, 0)

different_direction_matrix_df = pd.DataFrame(
    different_direction_matrix, index=diff_direction_genes, columns=diff_direction_genes
)

# %%
# Plot heatmap top similar genes

sns.set(rc={"figure.figsize": (48, 32)})
sns.set(font_scale=0.4)

f = sns.clustermap(
    same_direction_matrix_df,
    cmap="RdBu",
    vmin=-1,
    vmax=1,
    col_cluster=False,
    row_cluster=False,
)

f.ax_heatmap.set(xlabel="Genes", ylabel="Genes")
f.ax_heatmap.xaxis.label.set_size(12)
f.ax_heatmap.yaxis.label.set_size(12)
f.ax_heatmap.xaxis.set_tick_params(labelsize=8)
f.ax_heatmap.yaxis.set_tick_params(labelsize=8)
f.ax_heatmap.set_title(
    "ORF CRISPR top same direction gene pairs (abs cos sim > 0.6) not clustered", fontsize=16, y=1.25
)
f.savefig("figures/orf_crispr_top_same_direction_genes.png")
f.savefig("figures/orf_crispr_top_same_direction_genes.svg")

# %%
sns.set(rc={"figure.figsize": (48, 32)})
sns.set(font_scale=0.4)

f = sns.clustermap(
    different_direction_matrix_df,
    cmap="RdBu",
    vmin=-1,
    vmax=1,
    col_cluster=False,
    row_cluster=False,
)

f.ax_heatmap.set(xlabel="Genes", ylabel="Genes")
f.ax_heatmap.xaxis.label.set_size(12)
f.ax_heatmap.yaxis.label.set_size(12)
f.ax_heatmap.xaxis.set_tick_params(labelsize=8)
f.ax_heatmap.yaxis.set_tick_params(labelsize=8)
f.ax_heatmap.set_title(
    "ORF CRISPR top different direction gene pairs (abs cos sim > 0.6) not clustered",
    fontsize=16,
    y=1.25,
)
f.savefig("figures/orf_crispr_top_different_direction_genes.png")
f.savefig("figures/orf_crispr_top_different_direction_genes.svg")
