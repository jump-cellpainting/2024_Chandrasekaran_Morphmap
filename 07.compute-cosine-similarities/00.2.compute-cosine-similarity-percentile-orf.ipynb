# %%
import pandas as pd
from scipy.stats import rankdata

# %%
similarity_df = pd.read_parquet("cos_sim/cosine_similarities_genes_orf.parquet")

# %%
similarity_stacked = (
    similarity_df.stack()
    .reset_index()
    .rename(columns={0: "cosine_similarity", "level_0": "gene_1", "level_1": "gene_2"})
    .query("gene_1 != gene_2")
)

similarity_stacked["percentile"] = rankdata(similarity_stacked["cosine_similarity"], method="ordinal")/len(similarity_stacked)
similarity_stacked.head()
# Out:
#   gene_1   gene_2  cosine_similarity  percentile
# 1   CDK9     CDX1          -0.036738    0.245543
# 2   CDK9    DIDO1           0.024192    0.538784
# 3   CDK9  MORF4L1           0.088266    0.815902
# 4   CDK9   ZNF816           0.118091    0.893400
# 5   CDK9    CEBPG           0.193830    0.975086

# %%
similarity_percentile_df = similarity_stacked.pivot(index="gene_1", columns="gene_2", values="percentile").fillna(0)
similarity_percentile_df.head()
# Out:
# gene_2    A4GALT     A4GNT      AAAS     AADAT     AAGAB      AAK1     AAMDC  \
# gene_1
# A4GALT  0.000000  0.852932  0.490866  0.236811  0.720134  0.077355  0.898848
# A4GNT   0.852932  0.000000  0.211161  0.325677  0.883585  0.228999  0.417910
# AAAS    0.490866  0.211161  0.000000  0.902564  0.886572  0.291595  0.362734
# AADAT   0.236811  0.325677  0.902564  0.000000  0.534519  0.735789  0.509030
# AAGAB   0.720134  0.883585  0.886572  0.534519  0.000000  0.794831  0.576882
#
# gene_2     AANAT     AASDH  AASDHPPT  ...     ZPLD1    ZRANB2     ZRSR2  \
# gene_1                                ...
# A4GALT  0.847056  0.660895  0.937444  ...  0.995264  0.807002  0.460521
# A4GNT   0.418335  0.378002  0.772896  ...  0.789665  0.433726  0.737612
# AAAS    0.249736  0.447829  0.723394  ...  0.338451  0.409609  0.048216
# AADAT   0.121981  0.402996  0.966196  ...  0.269553  0.568686  0.899422
# AAGAB   0.702115  0.430625  0.402850  ...  0.798282  0.762077  0.250724
#
# gene_2    ZSCAN2   ZSCAN22   ZSCAN26   ZSCAN32   ZSCAN5A    ZWILCH     ZWINT
# gene_1
# A4GALT  0.681816  0.958971  0.300113  0.417821  0.385003  0.125498  0.863845
# A4GNT   0.603874  0.659854  0.571058  0.403227  0.159754  0.247597  0.227319
# AAAS    0.513181  0.438246  0.118001  0.693431  0.885243  0.838841  0.721651
# AADAT   0.695517  0.453887  0.772039  0.268820  0.548758  0.827092  0.282881
# AAGAB   0.858038  0.653416  0.075508  0.909977  0.605892  0.806337  0.340064
#
# [5 rows x 7031 columns]

# %%
similarity_percentile_df.to_parquet("cos_sim/cosine_similarities_percentile_genes_orf.parquet")
