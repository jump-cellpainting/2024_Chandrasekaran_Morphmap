# %%
import pandas as pd

# %% [markdown]
# Download the essentiality file (CRISPRGeneDependency.csv) from the DepMap portal (https://depmap.org/portal/download/all/?releasename=DepMap+Public+23Q4) and save it outside the repository.

# %%
dependency_df = pd.read_csv("../../CRISPRGeneDependency.csv").rename(
    columns={"Unnamed: 0": "ModelID"}
)
dependency_df.head()
# Out:
#       ModelID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0  ACH-000001  0.063550      0.017803  0.016486        0.066293
# 1  ACH-000004  0.016670      0.044559  0.035885        0.026364
# 2  ACH-000005  0.040757      0.022681  0.005047        0.008861
# 3  ACH-000007  0.018149      0.051901  0.006559        0.004373
# 4  ACH-000009  0.026656      0.115825  0.011635        0.011006
#
#    A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  AACS (65985)  \
# 0          0.029758        0.000815       0.023883     0.050448      0.003767
# 1          0.028644        0.020426       0.000832     0.045910      0.002606
# 2          0.064044        0.031699       0.004941     0.047061      0.036375
# 3          0.012135        0.003699       0.007898     0.107051      0.066871
# 4          0.014439        0.021746       0.011194     0.130169      0.018793
#
#    ...  ZWILCH (55055)  ZWINT (11130)  ZXDA (7789)  ZXDB (158586)  \
# ...

# %% [markdown]
# This file contains many cell lines. I then filter the dataframe to just the row for U2OS. The `ModelID` for U2OS is "ACH-000364" (obtained from [CPJUMP0 design](https://github.com/jump-cellpainting/jump-cellpainting/blob/f778f3998dab15997607061a44ad438ac0f1f560/0.design-pilots/4.create-perturbation-list.Rmd#L355))

# %%
dependency_df = (
    dependency_df.query('ModelID=="ACH-000364"')
    .transpose()
    .reset_index()
    .drop(index=0)
    .rename(columns={"index": "gene", 217: "probability"})
)

# %%
dependency_df[["Symbol", "geneID"]] = dependency_df["gene"].str.split(" ", expand=True)
dependency_df = dependency_df.assign(geneID=lambda x: x["geneID"].str[1:-1])

# %%
dependency_df[["geneID", "Symbol", "probability"]].to_csv(
    "output/CRISPRGeneDependency_U2OS.csv.gz", index=False
)

# %% [markdown]
# Download the expression file (OmicsExpressionProteinCodingGenesTPMLogp1.csv) from the DepMap portal (https://depmap.org/portal/download/all/?releasename=DepMap+Public+23Q4) and save it outside the repository.

# %%
expression_df = pd.read_csv(
    "../../OmicsExpressionProteinCodingGenesTPMLogp1.csv"
).rename(columns={"Unnamed: 0": "ModelID"})
expression_df.head()
# Out:
#       ModelID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0  ACH-001113       4.331992      0.000000     7.364660       2.792855
# 1  ACH-001289       4.567424      0.584963     7.106641       2.543496
# 2  ACH-001339       3.150560      0.000000     7.379118       2.333424
# 3  ACH-001538       5.085340      0.000000     7.154211       2.545968
# 4  ACH-000242       6.729417      0.000000     6.537917       2.456806
#
#    C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  ...  \
# 0          4.471187    0.028569    1.226509      3.044394     6.500005  ...
# 1          3.504620    0.000000    0.189034      3.813525     4.221877  ...
# 2          4.228049    0.056584    1.310340      6.687201     3.682573  ...
# 3          3.084064    0.000000    5.868390      6.165309     4.489928  ...
# 4          3.867896    0.799087    7.208478      5.570159     7.127117  ...
#
#    H3C2 (8358)  H3C3 (8352)  AC098582.1 (8916)  DUS4L-BCAP29 (115253422)  \
# ...

# %% [markdown]
# This file contains many cell lines. I then filter the dataframe to just the row for U2OS. The `ModelID` for U2OS is "ACH-000364" (obtained from [CPJUMP0 design](https://github.com/jump-cellpainting/jump-cellpainting/blob/f778f3998dab15997607061a44ad438ac0f1f560/0.design-pilots/4.create-perturbation-list.Rmd#L355))

# %%
expression_df = (
    expression_df.query('ModelID=="ACH-000364"')
    .transpose()
    .reset_index()
    .drop(index=0)
    .rename(columns={"index": "gene", 881: "TPM"})
)

# %%
expression_df[["Symbol", "geneID"]] = expression_df["gene"].str.split(" ", expand=True)
expression_df = expression_df.assign(geneID=lambda x: x["geneID"].str[1:-1])

# %%
expression_df[["geneID", "Symbol", "TPM"]].to_csv(
    "output/OmicsExpressionProteinCodingGenesTPMLogp1_U2OS.csv.gz", index=False
)
